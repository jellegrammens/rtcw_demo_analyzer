# %%
import os, sys
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#import the functions
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import rtcw_functions_custom as RTCW
reload(RTCW)

# db_name = 'cb.db'
# demos_folder = 'demoscb'

db_name = 'be.db'
demos_folder = 'demosbe'

cwd = os.getcwd()
demos_path = os.path.join(cwd, '../', demos_folder)

exe_name = 'Anders.Gaming.LibTech3.exe'
root_path = 'C:\\Users\\Jelle\\Documents\\GIT\\rtcw_demo_analyzer' #for executable we need a direct path

# %%
#get demos_dct
demos_dct = RTCW.make_dictionary(demos_path)
# Out:
# finished parsing all matches!

# %%
#load obituaries in a df
import sqlite3_connector
db = sqlite3_connector.sqlite3_connector(os.path.join(root_path, db_name))

# %%
obituary_df = db.get_table_as_df(table_name= 'obituary')
demo_df = db.get_table_as_df(table_name= 'demo')
player_df = db.get_table_as_df(table_name= 'player')
obituary_df = RTCW.add_match_data(obituary_df, player_df, demos_dct)
chatmessages_df = db.get_table_as_df(table_name= 'chatmessage')
chatmessages_df = RTCW.add_match_data(chatmessages_df, player_df, demos_dct, what_df = 'chatmessages_df')
chatmessages_df = RTCW.feature_extraction_chat(chatmessages_df)
# Out:
# obituary table fetched in 0.0 seconds
# demo table fetched in 0.0 seconds
# player table fetched in 0.0 seconds
# chatmessage table fetched in 0.0 seconds

# %%
df_spree = RTCW.get_kill_sprees(obituary_df, 
                                demo_df,
                                maxtime_secs = 20, 
                                include_weapon_filter = None,
                                exclude_weapon_filter = None, 
                                minspree = 3,
                                pov_sprees_only = False,
                                verbose = True)
# Out:
# all done!

# %%
df_spree[['match', 'demo', 'player', 'spreecount', 'weapons']]
# Out:
#       match                              demo         player  spreecount  \
# 0   demosbe         000508-Kevin-mp_ice.dm_60      Cliffdark           3
# 1   demosbe         000508-Kevin-mp_ice.dm_60          Du$ty           3
# 2   demosbe     001953-Kevin-te_escape2.dm_60          Du$ty           3
# 3   demosbe     001953-Kevin-te_escape2.dm_60          Kevin           3
# 4   demosbe     002625-Kevin-te_escape2.dm_60        Faster3           3
# 5   demosbe     002625-Kevin-te_escape2.dm_60        Fromiam           3
# 6   demosbe     002625-Kevin-te_escape2.dm_60          Du$ty           3
# 7   demosbe     002625-Kevin-te_escape2.dm_60          Kevin           3
# 8   demosbe        192624-oKevin-mp_ice.dm_60         O_Puma           3
# 9   demosbe        192624-oKevin-mp_ice.dm_60         O_Syl_           3
# 10  demosbe        192624-oKevin-mp_ice.dm_60  O_Dav1d_#2223           3
# 11  demosbe        192624-oKevin-mp_ice.dm_60  O_Homie_#9000           3
# 12  demosbe        193641-oKevin-mp_ice.dm_60        O_Kevin           3
# 13  demosbe        193641-oKevin-mp_ice.dm_60       O_Faster           4
# 14  demosbe        193641-oKevin-mp_ice.dm_60      Uk-crumbs           3
# 15  demosbe        193641-oKevin-mp_ice.dm_60    Uk-dictator           3
# 16  demosbe      200003-oKevin-mp_beach.dm_60      Uk-crumbs           3
# 17  demosbe      200003-oKevin-mp_beach.dm_60      Uk-crumbs           3
# 18  demosbe      200003-oKevin-mp_beach.dm_60        Uk-dtto           3
# 19  demosbe      200003-oKevin-mp_beach.dm_60         O_Puma           3
# 20  demosbe      201416-oKevin-mp_beach.dm_60       O_Faster           3
# 21  demosbe      201416-oKevin-mp_beach.dm_60      Uk-crumbs           3
# 22  demosbe  212040-oKevin-te_frostbite.dm_60  O_Dav1d_#2223           3
# 23  demosbe  212040-oKevin-te_frostbite.dm_60  O_Dav1d_#2223           3
# 24  demosbe  212040-oKevin-te_frostbite.dm_60        O_Kevin           5
# 25  demosbe  212040-oKevin-te_frostbite.dm_60  O_Homie_#9000           3
# 26  demosbe  212040-oKevin-te_frostbite.dm_60       O_Faster           3
# 27  demosbe  212040-oKevin-te_frostbite.dm_60         O_Puma           4
# 28  demosbe  212040-oKevin-te_frostbite.dm_60         O_Syl_           3
# 29  demosbe  213553-oKevin-te_frostbite.dm_60        O_Kevin           3
# ..      ...                               ...            ...         ...
# 31  demosbe  213553-oKevin-te_frostbite.dm_60        O_Kevin           3
# 32  demosbe  213553-oKevin-te_frostbite.dm_60        Eddo.nl           3
# 33  demosbe  213553-oKevin-te_frostbite.dm_60    Leonneke.nl           3
# 34  demosbe  213553-oKevin-te_frostbite.dm_60    Leonneke.nl           3
# 35  demosbe  213553-oKevin-te_frostbite.dm_60        Joep.nl           3
# 36  demosbe  213553-oKevin-te_frostbite.dm_60       Bully.nl           3
# 37  demosbe  213553-oKevin-te_frostbite.dm_60         Vis.nl           3
# 38  demosbe    220254-oKevin-mp_village.dm_60        Eddo.nl           3
# 39  demosbe    220254-oKevin-mp_village.dm_60       O_Faster           3
# 40  demosbe    221511-oKevin-mp_village.dm_60       O_Faster           3
# 41  demosbe    221511-oKevin-mp_village.dm_60         O_Syl_           3
# 42  demosbe    221511-oKevin-mp_village.dm_60         O_Puma           3
# 43  demosbe    221511-oKevin-mp_village.dm_60  O_Homie_#9000           3
# 44  demosbe    221511-oKevin-mp_village.dm_60  O_Dav1d_#2223           4
# 45  demosbe    222431-oKevin-mp_village.dm_60         Vis.nl           3
# 46  demosbe    222431-oKevin-mp_village.dm_60         Vis.nl           4
# 47  demosbe    222431-oKevin-mp_village.dm_60         Vis.nl           3
# 48  demosbe    222431-oKevin-mp_village.dm_60       Bully.nl           3
# 49  demosbe    222431-oKevin-mp_village.dm_60        Joep.nl           3
# 50  demosbe    222431-oKevin-mp_village.dm_60  O_Homie_#9000           3
# 51  demosbe    222431-oKevin-mp_village.dm_60      Crabje.nl           3
# 52  demosbe    222431-oKevin-mp_village.dm_60        O_Kevin           3
# 53  demosbe    222431-oKevin-mp_village.dm_60       O_Faster           3
# 54  demosbe      225228-oKevin-mp_beach.dm_60       O_Faster           3
# 55  demosbe      225228-oKevin-mp_beach.dm_60         Vis.nl           3
# 56  demosbe      225228-oKevin-mp_beach.dm_60        O_Kevin           3
# 57  demosbe      225228-oKevin-mp_beach.dm_60        O_Kevin           4
# 58  demosbe      225228-oKevin-mp_beach.dm_60       Bully.nl           3
# 59  demosbe      225228-oKevin-mp_beach.dm_60  O_Homie_#9000           3
# 60  demosbe      225228-oKevin-mp_beach.dm_60         O_Puma           3
#
#             weapons
# 0         46-17-17-
# 1         18-18-18-
# 2         18-18-16-
# 3           5-5-17-
# 4         18-18-18-
# 5         17-17-17-
# 6         18-18-18-
# 7         18-18-16-
# 8         17-17-17-
# 9          17-5-17-
# 10        18-18-18-
# 11           6-6-7-
# 12        17-46-17-
# 13       7-7-15-18-
# 14        18-18-18-
# 15        17-17-17-
# 16        46-46-17-
# 17        17-17-17-
# 18        21-21-21-
# 19        18-18-18-
# 20        21-21-21-
# 21        18-18-18-
# 22        18-18-18-
# 23        17-17-17-
# 24  49-46-49-46-46-
# 25          7-5-15-
# 26         46-5-17-
# 27     18-18-18-18-
# 28        17-17-17-
# 29        46-46-46-
# ..              ...
# 31          5-5-17-
# 32        17-17-17-
# 33        46-46-46-
# 34        17-49-17-
# 35          15-7-7-
# 36        17-46-46-
# 37        17-17-17-
# 38        17-17-17-
# 39        17-17-17-
# 40        17-46-46-
# 41        17-17-17-
# 42        17-17-17-
# 43           7-5-5-
# 44       5-5-17-17-
# 45        17-17-17-
# 46     17-17-15-15-
# 47        17-17-15-
# 48        46-46-46-
# 49          15-7-5-
# 50          17-5-5-
# 51        21-21-21-
# 52        46-46-46-
# 53        46-17-17-
# 54        17-17-17-
# 55        17-17-17-
# 56        17-17-49-
# 57      5-17-17-15-
# 58         5-17-16-
# 59           7-5-5-
# 60           5-5-5-
#
# [61 rows x 5 columns]

# %%
RTCW.cut_demos(root_path, demos_dct, df_spree, offset_start = 8, offset_end = 8, transform_to_dm_60 = True, demo_folder_name = demos_folder)
RTCW.generate_capture_list(df_spree, transform_to_dm_60 = True, follow_mode = False)

# %%
res = RTCW.get_docruns(chatmessages_df, 
                       min_docrun_length = 10, 
                       max_timeleft = 30, 
                       docs_succesful = None, 
                       min_docs_lost = 2, 
                       verbose = True)
res[['start', 'end', 'start_secsleft', 'end_secsleft', 'duration', 'times_lost_docs', 'won_round', 'md5']]

# %%
RTCW.cut_demos(root_path, demos_dct, res, demo_type = 'docs', offset_start = 8, offset_end = 8, transform_to_dm_60 = True, demo_folder_name= 'demos')
RTCW.generate_capture_list(res, demo_type='docs', transform_to_dm_60 = True)

# %%
df_wtv = RTCW.get_wtvmoments(chatmessages_df, z = 7, window = 10, verbose=True)
df_wtv

# %%
RTCW.cut_demos(root_path, demos_dct, df_wtv, demo_type = 'wtv', offset_start = 15, offset_end = 8, transform_to_dm_60 = True, demo_folder_name= 'demos')
RTCW.generate_capture_list(df_wtv, demo_type='wtv', transform_to_dm_60 = True)
