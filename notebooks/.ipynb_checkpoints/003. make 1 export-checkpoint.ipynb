# %%
import os, sys
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#import the functions
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import rtcw_functions as RTCW
reload(RTCW)

db_name = 'cb.db'
demos_folder = 'demoscb'

cwd = os.getcwd()
demos_path = os.path.join(cwd, '../', demos_folder)

exe_name = 'Anders.Gaming.LibTech3.exe'
demos_folder = 'demos'
root_path = 'C:\\Users\\Jelle\\Documents\\GIT\\rtcw_demo_analyzer' #for executable we need a direct path

# %%
#get demos_dct
demos_dct = RTCW.make_dictionary(demos_path)

# %%
#load obituaries in a df
import sqlite3_connector
db = sqlite3_connector.sqlite3_connector(os.path.join(root_path, db_name))

# %%
obituary_df = db.get_table_as_df(table_name= 'obituary')
demo_df = db.get_table_as_df(table_name= 'demo')
player_df = db.get_table_as_df(table_name= 'player')
obituary_df = RTCW.add_match_data(obituary_df, player_df, demos_dct)
chatmessages_df = db.get_table_as_df(table_name= 'chatmessage')
chatmessages_df = RTCW.add_match_data(chatmessages_df, player_df, demos_dct, what_df = 'chatmessages_df')
chatmessages_df = RTCW.feature_extraction_chat(chatmessages_df)

# %%
obituary_df = obituary_df[obituary_df['matchName'] == 'rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc']

# %%
obituary_df.demoName.unique()

# %%
obituary_df = obituary_df[obituary_df.szCleanName == "eH|zam"]

# %%
obituary_df = obituary_df[obituary_df.demoName == '213058-WTV-TnX-mp_beach.dm_60']

# %%
obituary_df
# Out:
#        dwSeq                             szMd5  bAttacker  bTarget  bWeapon  \
# 33070  33071  1c1832f62b9bd31c9fabfc46fcc8f672          2        4        5
# 33116  33117  1c1832f62b9bd31c9fabfc46fcc8f672          2        0       46
# 33138  33139  1c1832f62b9bd31c9fabfc46fcc8f672          2        2       56
# 33147  33148  1c1832f62b9bd31c9fabfc46fcc8f672          2       12       17
# 33149  33150  1c1832f62b9bd31c9fabfc46fcc8f672          2        9       17
# 33161  33162  1c1832f62b9bd31c9fabfc46fcc8f672          2        2       56
# 33198  33199  1c1832f62b9bd31c9fabfc46fcc8f672          2        2       56
# 33207  33208  1c1832f62b9bd31c9fabfc46fcc8f672          2        0       17
# 33267  33268  1c1832f62b9bd31c9fabfc46fcc8f672          2        2       56
# 33271  33272  1c1832f62b9bd31c9fabfc46fcc8f672          2       16       46
# 33280  33281  1c1832f62b9bd31c9fabfc46fcc8f672          2        9       17
# 33306  33307  1c1832f62b9bd31c9fabfc46fcc8f672          2       16       17
# 33330  33331  1c1832f62b9bd31c9fabfc46fcc8f672          2        0       17
# 33351  33352  1c1832f62b9bd31c9fabfc46fcc8f672          2        2       56
# 33353  33354  1c1832f62b9bd31c9fabfc46fcc8f672          2       16       49
# 33359  33360  1c1832f62b9bd31c9fabfc46fcc8f672          2       16       17
# 33368  33369  1c1832f62b9bd31c9fabfc46fcc8f672          2        9       17
# 33369  33370  1c1832f62b9bd31c9fabfc46fcc8f672          2       10       17
# 33378  33379  1c1832f62b9bd31c9fabfc46fcc8f672          2        4        5
# 33412  33413  1c1832f62b9bd31c9fabfc46fcc8f672          2       16       17
# 33415  33416  1c1832f62b9bd31c9fabfc46fcc8f672          2       15       17
# 33437  33438  1c1832f62b9bd31c9fabfc46fcc8f672          2        2       56
# 33441  33442  1c1832f62b9bd31c9fabfc46fcc8f672          2        9       17
# 33443  33444  1c1832f62b9bd31c9fabfc46fcc8f672          2       15       17
# 33450  33451  1c1832f62b9bd31c9fabfc46fcc8f672          2        2       56
# 33476  33477  1c1832f62b9bd31c9fabfc46fcc8f672          2        9       17
# 33488  33489  1c1832f62b9bd31c9fabfc46fcc8f672          2        9        5
# 33490  33491  1c1832f62b9bd31c9fabfc46fcc8f672          2       15        5
#
#         dwTime  bIsTeamkill szTimeString  \
# 33070   777600            0         7:09
# 33116   920250            0         4:46
# 33138  1004900            1         3:21
# 33147  1023350            1         3:03
# 33149  1029850            0         2:56
# 33161  1166400            1         4:43
# 33198  1286300            1         2:43
# 33207  1325300            0         2:04
# 33267  1569200            1         6:43
# 33271  1590350            0         6:22
# 33280  1622900            0         5:49
# 33306  1721400            0         4:11
# 33330  1832750            0         2:20
# 33351  1901100            1         1:11
# 33353  1906800            0         1:06
# 33359  1939500            0         0:33
# 33368  1962350            0         0:10
# 33369  1964050            0         0:08
# 33378  2069850            0         7:36
# 33412  2203650            0         5:22
# 33415  2223000            0         5:02
# 33437  2277650            1         4:08
# 33441  2294500            0         3:51
# 33443  2299650            0         3:46
# 33450  2318100            1         3:27
# 33476  2409200            0         1:56
# 33488  2474650            0         0:51
# 33490  2483050            0         0:42
#
#                                               szMessage       Date Importance  \
# 33070        KiH.FeTTe was exploded by eH|zam's grenade 2004-12-16     finals
# 33116  KiH.smutzig was blasted by eH|zam's support fire 2004-12-16     finals
# 33138                            eH|zam killed himself. 2004-12-16     finals
# 33147               eH|SoD! was killed by eH|zam's MP40 2004-12-16     finals
# 33149              KiH.wuff was killed by eH|zam's MP40 2004-12-16     finals
# 33161                            eH|zam killed himself. 2004-12-16     finals
# 33198                            eH|zam killed himself. 2004-12-16     finals
# 33207           KiH.smutzig was killed by eH|zam's MP40 2004-12-16     finals
# 33267                            eH|zam killed himself. 2004-12-16     finals
# 33271    KiH.zerom was blasted by eH|zam's support fire 2004-12-16     finals
# 33280              KiH.wuff was killed by eH|zam's MP40 2004-12-16     finals
# 33306             KiH.zerom was killed by eH|zam's MP40 2004-12-16     finals
# 33330           KiH.smutzig was killed by eH|zam's MP40 2004-12-16     finals
# 33351                            eH|zam killed himself. 2004-12-16     finals
# 33353                    KiH.zerom was killed by eH|zam 2004-12-16     finals
# 33359             KiH.zerom was killed by eH|zam's MP40 2004-12-16     finals
# 33368              KiH.wuff was killed by eH|zam's MP40 2004-12-16     finals
# 33369             KiH.riven was killed by eH|zam's MP40 2004-12-16     finals
# 33378        KiH.FeTTe was exploded by eH|zam's grenade 2004-12-16     finals
# 33412             KiH.zerom was killed by eH|zam's MP40 2004-12-16     finals
# 33415            KiH.arnjee was killed by eH|zam's MP40 2004-12-16     finals
# 33437                            eH|zam killed himself. 2004-12-16     finals
# 33441              KiH.wuff was killed by eH|zam's MP40 2004-12-16     finals
# 33443            KiH.arnjee was killed by eH|zam's MP40 2004-12-16     finals
# 33450                            eH|zam killed himself. 2004-12-16     finals
# 33476              KiH.wuff was killed by eH|zam's MP40 2004-12-16     finals
# 33488         KiH.wuff was exploded by eH|zam's grenade 2004-12-16     finals
# 33490       KiH.arnjee was exploded by eH|zam's grenade 2004-12-16     finals
#
#         League  TeamA TeamB                                    demoName  \
# 33070  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33116  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33138  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33147  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33149  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33161  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33198  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33207  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33267  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33271  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33280  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33306  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33330  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33351  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33353  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33359  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33368  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33369  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33378  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33412  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33415  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33437  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33441  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33443  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33450  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33476  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33488  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# 33490  cb-ec10  emaho   kih  EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
#
#                                             matchName  Shoutcast szCleanName
# 33070  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33116  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33138  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33147  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33149  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33161  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33198  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33207  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33267  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33271  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33280  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33306  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33330  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33351  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33353  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33359  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33368  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33369  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33378  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33412  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33415  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33437  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33441  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33443  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33450  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33476  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33488  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam
# 33490  rtcw_2004.12.16_cb-ec10_emaho_vs_kih_finals_sc       True      eH|zam

# %%
obits = obituary_df.iloc[[4]]
obits
# Out:
#        dwSeq                             szMd5  bAttacker  bTarget  bWeapon  \
# 83855  83856  e759ddacddba9d350a13e5d5a73bc39b         12        1       17
#
#          dwTime  bIsTeamkill szTimeString  \
# 83855  56812800            0         1:14
#
#                                         szMessage       Date   Importance  \
# 83855  eH|civ was killed by dignitas syler's MP40 2004-12-12  semi-finals
#
#         League     TeamA  TeamB  \
# 83855  cb-ec10  dignitas  emaho
#
#                                                demoName  \
# 83855  ECX_dignitas_vs_emaho_SEMIFINALS_mp_beach4.dm_60
#
#                                                matchName  Shoutcast  \
# 83855  rtcw_2004.12.12_cb-ec10_dignitas_vs_emaho_semi...       True
#
#           szCleanName
# 83855  dignitas syler

# %%
df_spree = RTCW.get_kill_sprees(obits, 
                                demo_df,
                                maxtime_secs = 4, 
                                include_weapon_filter = None,
                                exclude_weapon_filter = None, 
                                minspree = 1,
                                pov_sprees_only = False,
                                verbose = True)
# Out:
# all done!

# %%
df_spree[['match', 'demo', 'player', 'spreecount', 'weapons']]
# Out:
#                                                match  \
# 0  rtcw_2004.12.12_cb-ec10_dignitas_vs_emaho_semi...
#
#                                                demo          player  \
# 0  ECX_dignitas_vs_emaho_SEMIFINALS_mp_beach4.dm_60  Dignitas_Syler
#
#    spreecount weapons
# 0           1     17-

# %%
RTCW.cut_demos(root_path, demos_dct, df_spree, offset_start = 8, offset_end = 800, transform_to_dm_60 = True)
RTCW.generate_capture_list(df_spree, transform_to_dm_60 = True)

# %%
# Out:
#        dwSeq                             szMd5  bAttacker  bTarget  bWeapon  \
# 62141  62142  72e51f702a2a0e67edad6b280c051dd6         14       13       18
#
#            dwTime  bIsTeamkill szTimeString  \
# 62141  1763773000            0         0:03
#
#                                            szMessage       Date Importance  \
# 62141  NL-Jehuty was killed by mayh3M <o/'s Thompson 2005-02-01     finals
#
#        League TeamA TeamB                       demoName  \
# 62141  cb-nc7   bel   ned  230829-NL-KeZZa!-mp_ice.dm_60
#
#                                       matchName  Shoutcast szCleanName
# 62141  rtcw_2005.02.01_cb-nc7_bel_vs_ned_finals      False  mayh3M <o/
