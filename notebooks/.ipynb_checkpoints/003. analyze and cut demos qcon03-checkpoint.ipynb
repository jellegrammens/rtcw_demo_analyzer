# %%
import os, sys
import pandas as pd

#import the functions
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import rtcw_functions as RTCW
reload(RTCW)

db_name = 'qcon03.db'
demos_folder = 'demosqcon03'
cwd = os.getcwd()
demos_path = os.path.join(cwd, '../', demos_folder)

exe_name = 'Anders.Gaming.LibTech3.exe'
root_path = 'C:\\Users\\Jelle\\Documents\\GIT\\rtcw_demo_analyzer' #for executable we need a direct path

# %%
#get demos_dct
demos_dct = RTCW.make_dictionary(demos_path)
# Out:
# finished parsing all matches!

# %%
#load obituaries in a df
import sqlite3_connector
reload(sqlite3_connector)
db = sqlite3_connector.sqlite3_connector(os.path.join(root_path, db_name))

# %%
obituary_df = db.get_table_as_df(table_name= 'obituary')
demo_df = db.get_table_as_df(table_name= 'demo')
player_df = db.get_table_as_df(table_name= 'player')
obituary_df = RTCW.add_match_data(obituary_df, player_df, demos_dct)
obituary_df = obituary_df.loc[obituary_df['League'] == 'qcon03']
obituary_df = obituary_df.loc[obituary_df['Importance'].isin(['lb-round1', 'wb-round2', 'lb-round2'])]
# Out:
# obituary table fetched in 0.29 seconds
# demo table fetched in 0.01 seconds
# player table fetched in 0.02 seconds

# %%
df_spree = RTCW.get_kill_sprees(obituary_df, 
                                demo_df,
                                maxtime_secs = 20, 
                                include_weapon_filter = None,
                                exclude_weapon_filter = None, 
                                minspree = 5,
                                pov_sprees_only = False,
                                verbose = True)
# Out:
# scanned 100 demos of 372 demos in total
# scanned 200 demos of 372 demos in total
# scanned 300 demos of 372 demos in total
# all done!

# %%
df_spree[['match', 'demo', 'player', 'spreecount', 'weapons', 'attacker', 'pov_id']]
# Out:
#                                                  match  \
# 0          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 1          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 2          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 3          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 4          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 5          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 6          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 7          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 8          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 9          rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 10         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 11         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 12         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 13         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 14         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 15         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 16         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 17         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 18         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 19         rtcw_2003.08.15_qcon03_narf_vs_ck_lb-round2
# 20        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 21        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 22        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 23        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 24        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 25        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 26        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 27        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 28        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 29        rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# ..                                                 ...
# 88   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 89   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 90   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 91   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 92   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 93   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 94   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 95   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 96   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 97   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 98   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 99   rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 100  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 101  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 102  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 103  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 104  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 105  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 106  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 107  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 108  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 109  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 110  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 111  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 112  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 113  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 114  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 115  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 116  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 117  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
#
#                                                   demo       player  \
# 0      2002-08-17_223513-IMMorTAL]NARF[-mp_beach.dm_60     Ck_Se7en
# 1      2002-08-17_223513-IMMorTAL]NARF[-mp_beach.dm_60  Ck_Apoculos
# 2          2003-08-15_223618-cKanimeman-mp_beach.dm_60     Ck_Se7en
# 3          2003-08-15_223618-cKanimeman-mp_beach.dm_60  Ck_Apoculos
# 4          2003-08-15_224624-cKApoculos-mp_beach.dm_60     Ck_Se7en
# 5          2003-08-15_224624-cKApoculos-mp_beach.dm_60  Ck_Apoculos
# 6             2003-08-15_223238-cKse7en-mp_beach.dm_60     Ck_Se7en
# 7             2003-08-15_223238-cKse7en-mp_beach.dm_60  Ck_Apoculos
# 8          2003-08-15_223328-cKshaftian-mp_beach.dm_60     Ck_Se7en
# 9          2003-08-15_223328-cKshaftian-mp_beach.dm_60  Ck_Apoculos
# 10           2003-08-15_223104-cKpravda-mp_beach.dm_60     Ck_Se7en
# 11           2003-08-15_223104-cKpravda-mp_beach.dm_60  Ck_Apoculos
# 12           2003-08-15_223221-cKinmojo-mp_beach.dm_60     Ck_Se7en
# 13           2003-08-15_223221-cKinmojo-mp_beach.dm_60  Ck_Apoculos
# 14         2003-08-15_233158-cKanimeman-mp_beach.dm_60    Ck_Inmojo
# 15   2002-08-17_233052-Sir_Shaggy]NARF[-mp_beach.dm_60    Ck_Inmojo
# 16           2003-08-15_232643-cKpravda-mp_beach.dm_60    Ck_Inmojo
# 17           2003-08-15_232800-cKinmojo-mp_beach.dm_60    Ck_Inmojo
# 18            2003-08-15_232817-cKse7en-mp_beach.dm_60    Ck_Inmojo
# 19         2003-08-15_234203-cKApoculos-mp_beach.dm_60    Ck_Inmojo
# 20           2003-08-15_144831-wSwscorp-mp_beach.dm_60   Wswlaws_69
# 21           2003-08-15_144831-wSwscorp-mp_beach.dm_60  Lynch]narf[
# 22            2003-08-15_145146-wSwslaG-mp_beach.dm_60   Wswlaws_69
# 23            2003-08-15_145146-wSwslaG-mp_beach.dm_60  Lynch]narf[
# 24      2003-08-15_145342-wSweVilkillEr-mp_beach.dm_60   Wswlaws_69
# 25      2003-08-15_145342-wSweVilkillEr-mp_beach.dm_60  Lynch]narf[
# 26         2003-08-15_145630-wSwlaws_69-mp_beach.dm_60   Wswlaws_69
# 27         2003-08-15_145630-wSwlaws_69-mp_beach.dm_60  Lynch]narf[
# 28        2003-08-15_144516-wSwImpulse_-mp_beach.dm_60   Wswlaws_69
# 29        2003-08-15_144516-wSwImpulse_-mp_beach.dm_60  Lynch]narf[
# ..                                                 ...          ...
# 88           2003-08-15_100913-lc-duSty-mp_beach.dm_60   4k^yilider
# 89         2003-08-15_100933-4K7HaRdNuT-mp_beach.dm_60   4k^yilider
# 90          2003-08-15_101853-4K7Ogdoad-mp_beach.dm_60   4k^yilider
# 91            2003-08-15_101711-lc-papa-mp_beach.dm_60   4k^yilider
# 92           2003-08-15_101743-4K7Zommy-mp_beach.dm_60   4k^yilider
# 93          2003-08-15_102945-4K7Ogdoad-mp_beach.dm_60   4k^yilider
# 94          2003-08-15_102945-4K7Ogdoad-mp_beach.dm_60   4k^yilider
# 95             2003-08-15_101922-lc-taz-mp_beach.dm_60   4k^yilider
# 96             2003-08-15_101922-lc-taz-mp_beach.dm_60   4k^yilider
# 97    2003-08-15_102321-lc-chaKchaKchaK-mp_beach.dm_60   4k^yilider
# 98    2003-08-15_102321-lc-chaKchaKchaK-mp_beach.dm_60   4k^yilider
# 99             2003-08-15_101716-lc-asl-mp_beach.dm_60   4k^yilider
# 100            2003-08-15_101716-lc-asl-mp_beach.dm_60   4k^yilider
# 101          2003-08-15_102005-lc-duSty-mp_beach.dm_60   4k^yilider
# 102          2003-08-15_102005-lc-duSty-mp_beach.dm_60   4k^yilider
# 103       2003-08-15_102233-4K7Explicit-mp_beach.dm_60   4k^yilider
# 104       2003-08-15_102233-4K7Explicit-mp_beach.dm_60   4k^yilider
# 105        2003-08-15_102523-4K7Yilider-mp_beach.dm_60   4k^yilider
# 106        2003-08-15_102523-4K7Yilider-mp_beach.dm_60   4k^yilider
# 107         2003-08-15_102612-4K7Creamy-mp_beach.dm_60   4k^yilider
# 108         2003-08-15_102612-4K7Creamy-mp_beach.dm_60   4k^yilider
# 109           2003-08-15_102804-lc-papa-mp_beach.dm_60   4k^yilider
# 110           2003-08-15_102804-lc-papa-mp_beach.dm_60   4k^yilider
# 111        2003-08-15_102025-4K7HaRdNuT-mp_beach.dm_60   4k^yilider
# 112        2003-08-15_102025-4K7HaRdNuT-mp_beach.dm_60   4k^yilider
# 113          2003-08-15_102835-4K7Zommy-mp_beach.dm_60   4k^yilider
# 114          2003-08-15_102835-4K7Zommy-mp_beach.dm_60   4k^yilider
# 115                     171409-4K7Zommy-mp_beach.dm_60   4k^yilider
# 116                    172501-4K7Creamy-mp_beach.dm_60   4k^yilider
