# %%
import os, sys
import sqlite3
import pandas as pd

#import the functions
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)

db_name = 'rtcw_db.db'
demos_folder = 'demos'

cwd = os.getcwd()
root_path = os.path.join(cwd, '../')
demos_path = os.path.join(cwd, '../', demos_folder)

# %%
#get demos_dct
import rtcw_functions as RTCW
demos_dct = RTCW.make_dictionary(demos_path)
# Out:
# parsed 100 demos
# parsed 200 demos
# parsed 300 demos
# parsed 400 demos
# finished parsing all demos!

# %%
import sqlite3_connector
reload(sqlite3_connector)
db = sqlite3_connector.sqlite3_connector(os.path.join(root_path, db_name))

# %%
db.get_table_names()
# Out:
# array([u'demo', u'sqlite_sequence', u'chatmessage', u'obituary',
#        u'bulletevent', u'player', u'roundstats'], dtype=object)

# %%
obituary_df = db.get_table_as_df(table_name= 'obituary')
# Out:
# obituary table fetched in 0.61 seconds

# %%
len(obituary_df)
# Out:
# 151233

# %%
obituary_df.szMessage[0:5].values
# Out:
# array([u'[DSB]Swimding was killed by f|murasame',
#        u"f|murasame was exploded by f|leethal's grenade",
#        u'f|valdez was killed by f|z0rr0',
#        u'f|z0rr0 was killed by [DSB]SnipeTX',
#        u"[DSB]SnotRag was exploded by f|d@n!el's grenade"], dtype=object)

# %%
obituary_df
# Out:
#          dwSeq                             szMd5  bAttacker  bTarget  bWeapon  \
# 0            1  6f7605523ed948dcb2ea7090afbcc447          6       12        5
# 1            2  6f7605523ed948dcb2ea7090afbcc447          2        6       18
# 2            3  6f7605523ed948dcb2ea7090afbcc447          8        3        5
# 3            4  6f7605523ed948dcb2ea7090afbcc447         16        8        5
# 4            5  6f7605523ed948dcb2ea7090afbcc447          5        9       18
# 5            6  6f7605523ed948dcb2ea7090afbcc447         16        2        5
# 6            7  6f7605523ed948dcb2ea7090afbcc447          3       16       17
# 7            8  6f7605523ed948dcb2ea7090afbcc447         12        3       17
# 8            9  6f7605523ed948dcb2ea7090afbcc447          1       14       17
# 9           10  6f7605523ed948dcb2ea7090afbcc447         10        6       17
# 10          11  6f7605523ed948dcb2ea7090afbcc447          5        1       16
# ...

# %%
demo = demos_dct['rtcw_2002.11.30_cb-nc3_pol_vs_lat_groupstage']
md5 = demo[0]
demo_names = demo[1]
df = obituary_df.loc[obituary_df['szMd5'] == md5[0]]

# %%
def get_sec(time_str):
    m, s = time_str.split(':')
    return int(m) * 60 + int(s)

df['secs_left_round'] = df.szTimeString.apply(get_sec)
# Out:
# C:\Users\JelleGrammens\Anaconda2\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
for row in range(len(df)):
# Out:
#          dwSeq                             szMd5  bAttacker  bTarget  bWeapon  \
# 145023  145024  d31c87d84c2dda10302b31b5da94993b          9        6       17
# 145024  145025  d31c87d84c2dda10302b31b5da94993b          9        6       17
# 145025  145026  d31c87d84c2dda10302b31b5da94993b          6        9        7
# 145026  145027  d31c87d84c2dda10302b31b5da94993b          0        5        7
# 145027  145028  d31c87d84c2dda10302b31b5da94993b          0        4        7
# 145028  145029  d31c87d84c2dda10302b31b5da94993b          0        7        7
# 145029  145030  d31c87d84c2dda10302b31b5da94993b         13        8       17
# 145030  145031  d31c87d84c2dda10302b31b5da94993b         12       11       18
# 145031  145032  d31c87d84c2dda10302b31b5da94993b          2        6       17
# 145032  145033  d31c87d84c2dda10302b31b5da94993b          2        2       56
# 145033  145034  d31c87d84c2dda10302b31b5da94993b         13        7       17
# ...

# %%
#only need numerical columns and np is way faster than pandas anyways
df_cut = df.loc[df['bAttacker'] == 6]
arr = df_cut.as_matrix(columns = ['bAttacker', 'bTarget', 'bIsTeamkill', 'dwTime'])

# %%
arr.shape
# Out:
# (37L, 4L)

# %%
arr[:2]
# Out:
# array([[      6,       9,       0, 2731450],
#        [      6,      13,       0, 2826850]], dtype=int64)

# %%
df.bAttacker.unique()
# Out:
# array([ 9,  6,  0, 13, 12,  2,  5, 11,  8,  4,  3,  7, 10], dtype=int64)

# %%
list_sprees = []
for player in df.bAttacker.unique():
    df_cut = df.loc[df['bAttacker'] == player]
    arr = df_cut.as_matrix(columns = ['bAttacker', 'bTarget', 'bIsTeamkill', 'dwTime'])
    
    timerestriction = 30 * 1000 #30 secs
    minspree = 3
    spreecounter = 0
    
    temp_sprees = []
    total_rows = len(arr)

    for row in range(len(arr)):
        frag = arr[row, :]

        #init first_spreetime
        if row == 0:
            first_spreetime = frag[3]
            temp_sprees.append(first_spreetime)

        #if current frag is in the timerestriction
        if frag[3] - first_spreetime <= timerestriction:
            if (frag[0] != frag[1]) and (frag[2] != 1):
                spreecounter += 1
                temp_sprees.append(frag[3])

        #if not output a list with start and end time of the spree if condition is met
        else:
            if spreecounter >= minspree:
                list_sprees.append(temp_sprees)

            if (frag[0] != frag[1]) and (frag[2] != 1):
                spreecounter = 1
                first_spreetime = frag[3]   
                temp_sprees = []
                temp_sprees.append(first_spreetime)

            else:
                spreecounter = 0
                first_spreetime = frag[3]   
                temp_sprees = []

        #if last frag in the data
        if row == (total_rows - 1):
            if spreecounter >= minspree:
                list_sprees.append(temp_sprees)

# %%
list_sprees = []
timerestriction = 30 * 1000 #30 secs
minspree = 3
spreecounter = 0

temp_sprees = []
total_rows = len(arr)

for row in range(len(arr)):
    frag = arr[row, :]

    #init first_spreetime
    if row == 0:
        first_spreetime = frag[3]
        temp_sprees.append(first_spreetime)

    #if current frag is in the timerestriction
    if frag[3] - first_spreetime <= timerestriction:
        if (frag[0] != frag[1]) and (frag[2] != 1):
            spreecounter += 1
            temp_sprees.append(frag[3])

    #if not output a list with start and end time of the spree if condition is met
    else:
        if spreecounter >= minspree:
            list_sprees.append(temp_sprees)

        if (frag[0] != frag[1]) and (frag[2] != 1):
            spreecounter = 1
            first_spreetime = frag[3]   
            temp_sprees = []
            temp_sprees.append(first_spreetime)

        else:
            spreecounter = 0
            first_spreetime = frag[3]   
            temp_sprees = []

    #if last frag in the data
    if row == (total_rows - 1):
        if spreecounter >= minspree:
            list_sprees.append(temp_sprees)

# %%
list_sprees
# Out:
# [[3159950, 3159950, 3169350],
#  [4870300, 4870300, 4870300],
#  [4919700, 4919700, 4933650, 4940200],
#  [4966300, 4966300, 4966300],
#  [5321200, 5321200, 5321200, 5321200, 5321200],
#  [2735850, 2735850, 2735850, 2735850],
#  [3034400, 3034400, 3034400],
#  [5139900, 5140900, 5167250],
#  [4017350, 4034000, 4034000, 4036250],
#  [3929050, 3953250, 3953500],
#  [3141100, 3142950, 3150100],
#  [4928050, 4937400, 4943900],
#  [4895050, 4895350, 4913450],
#  [5168500, 5168500, 5193250],
#  [5206100, 5206450, 5220250]]

# %%
df.loc[df['dwTime'].isin(list_sprees[6])]
# Out:
#          dwSeq                             szMd5  bAttacker  bTarget  bWeapon  \
# 145044  145045  d31c87d84c2dda10302b31b5da94993b          0        8        7
# 145045  145046  d31c87d84c2dda10302b31b5da94993b          0        6        7
# 145046  145047  d31c87d84c2dda10302b31b5da94993b          0        5        7
#
#          dwTime  bIsTeamkill szTimeString  \
# 145044  3034400            0        12:02
# 145045  3034400            0        12:02
# 145046  3034400            0        12:02
#
#                                                szMessage  secs_left_round
# 145044  Diablo LAT was killed by POL|Starsky's Luger 9mm              722
# 145045      Go LAT was killed by POL|Starsky's Luger 9mm              722
# 145046   raibs LAT was killed by POL|Starsky's Luger 9mm              722

# %%
#last frag in spree, yes bool
# Out:
# array([      9,       6, 2723250,       0], dtype=int64)

# %%
for player in df.bAttacker.unique():
    df_cut = df.loc[df['bAttacker'] == player]
    arr = df_cut.as_matrix(columns = ['bAttacker', 'bTarget', 'dwTime', 'bIsTeamkill'])

# %%
df_cut
# Out:
#          dwSeq                             szMd5  bAttacker  bTarget  bWeapon  \
# 145115  145116  d31c87d84c2dda10302b31b5da94993b         10       10       56
# 145197  145198  d31c87d84c2dda10302b31b5da94993b         10       13       46
# 145198  145199  d31c87d84c2dda10302b31b5da94993b         10        9       46
# 145199  145200  d31c87d84c2dda10302b31b5da94993b         10        0       17
# 145206  145207  d31c87d84c2dda10302b31b5da94993b         10        0       17
# 145210  145211  d31c87d84c2dda10302b31b5da94993b         10        2       17
# 145216  145217  d31c87d84c2dda10302b31b5da94993b         10       13       17
# 145227  145228  d31c87d84c2dda10302b31b5da94993b         10       11       17
# 145233  145234  d31c87d84c2dda10302b31b5da94993b         10        3       17
# 145237  145238  d31c87d84c2dda10302b31b5da94993b         10       11       17
# 145249  145250  d31c87d84c2dda10302b31b5da94993b         10        3        5
# ...
