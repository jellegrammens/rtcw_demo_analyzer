# %%
import os, sys
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#import the functions
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import rtcw_functions as RTCW
reload(RTCW)

db_name = 'rtcw_db.db'
demos_folder = 'demos'

cwd = os.getcwd()
demos_path = os.path.join(cwd, '../', demos_folder)

exe_name = 'Anders.Gaming.LibTech3.exe'
demos_folder = 'demos'
root_path = 'C:\\Users\\Jelle\\Documents\\GIT\\rtcw_demo_analyzer' #for executable we need a direct path

# %%
#get demos_dct
demos_dct = RTCW.make_dictionary(demos_path)
# Out:
# parsed 100 matches
# parsed 200 matches
# parsed 300 matches
# parsed 400 matches
# finished parsing all matches!

# %%
#load obituaries in a df
import sqlite3_connector
reload(sqlite3_connector)
db = sqlite3_connector.sqlite3_connector(os.path.join(root_path, db_name))

# %%
obituary_df = db.get_table_as_df(table_name= 'obituary')
demo_df = db.get_table_as_df(table_name= 'demo')
player_df = db.get_table_as_df(table_name= 'player')
obituary_df = RTCW.add_match_data(obituary_df, player_df, demos_dct)
#obituary_df = obituary_df.loc[obituary_df['League'] == 'qcon02']
#obituary_df = obituary_df.loc[obituary_df['Importance'] == 'wb-round1']
# Out:
# obituary table fetched in 0.49 seconds
# demo table fetched in 0.02 seconds
# player table fetched in 0.05 seconds

# %%
obituary_df = obituary_df.loc[obituary_df['League'] == 'cb-nc3']

# %%
df_spree = RTCW.get_kill_sprees(obituary_df, 
                                demo_df,
                                maxtime_secs = 30, 
                                include_weapon_filter = None,
                                exclude_weapon_filter = None, 
                                minspree = 5,
                                pov_sprees_only = False,
                                verbose = True)
# Out:
# all done!

# %%
df_spree[['match', 'demo', 'player', 'spreecount', 'weapons']]
# Out:
#                                                match  \
# 0       rtcw_2002.11.28_cb-nc3_ned_vs_aut_groupstage
# 1       rtcw_2002.11.28_cb-nc3_ned_vs_aut_groupstage
# 2       rtcw_2002.11.28_cb-nc3_ned_vs_aut_groupstage
# 3       rtcw_2002.11.28_cb-nc3_ned_vs_aut_groupstage
# 4       rtcw_2002.11.28_cb-nc3_ned_vs_aut_groupstage
# 5       rtcw_2002.11.28_cb-nc3_ned_vs_aut_groupstage
# 6       rtcw_2002.11.28_cb-nc3_ned_vs_aut_groupstage
# 7       rtcw_2002.11.26_cb-nc3_fin_vs_nor_groupstage
# 8       rtcw_2002.11.26_cb-nc3_fin_vs_nor_groupstage
# 9       rtcw_2002.11.26_cb-nc3_fin_vs_nor_groupstage
# 10      rtcw_2002.11.10_cb-nc3_ita_vs_por_qualifiers
# 11    rtcw_2003.02.07_cb-nc3_uk_vs_ger_bronze-finals
# 12      rtcw_2003.01.23_cb-nc3_swe_vs_uk_semi-finals
# 13      rtcw_2003.01.23_cb-nc3_swe_vs_uk_semi-finals
# 14      rtcw_2002.12.02_cb-nc3_swe_vs_rus_groupstage
# 15  rtcw_2003.01.09_cb-nc3_swe_vs_nor_quarter-finals
# 16      rtcw_2002.12.01_cb-nc3_ger_vs_ita_groupstage
# 17      rtcw_2002.12.01_cb-nc3_ger_vs_ita_groupstage
# 18  rtcw_2003.01.09_cb-nc3_ger_vs_ned_quarter-finals
# 19  rtcw_2003.01.09_cb-nc3_ger_vs_ned_quarter-finals
# 20  rtcw_2003.01.09_cb-nc3_ger_vs_ned_quarter-finals
# 21      rtcw_2002.11.30_cb-nc3_pol_vs_lat_groupstage
# 22      rtcw_2002.11.30_cb-nc3_pol_vs_lat_groupstage
# 23      rtcw_2002.11.30_cb-nc3_pol_vs_lat_groupstage
# 24      rtcw_2002.11.30_cb-nc3_pol_vs_lat_groupstage
# 25      rtcw_2002.11.30_cb-nc3_pol_vs_lat_groupstage
# 26      rtcw_2002.12.16_cb-nc3_swe_vs_den_groupstage
#
#                                       demo           player  spreecount  \
# 0      200752-NeonKnightjenl-mp_base.dm_60         Ramzi.nl           5
# 1      200752-NeonKnightjenl-mp_base.dm_60         Ramzi.nl           5
# 2      200752-NeonKnightjenl-mp_base.dm_60        Jappio.nl           5
# 3      200752-NeonKnightjenl-mp_base.dm_60        Voody.aut           5
# 4      203123-NeonKnightjenl-mp_base.dm_60        Jappio.nl           5
# 5      203857-NeonKnightjenl-mp_base.dm_60         Ramzi.nl           6
# 6   205650-NeonKnightjenl-mp_assault.dm_60        Jappio.nl           5
# 7      FIN_NOR_assault_chase_1440659.dm_60     Finisanctity           5
# 8      FIN_NOR_assault_chase_1440659.dm_60      Finichinese           5
# 9      FIN_NOR_assault_chase_1440659.dm_60         Finivera           5
# 10                           demo_04.dm_59      [_Ita-baz_]           6
# 11          222428-fizzel-mp_assault.dm_60            S4ber           5
# 12  224929-WTV-speakeasynet-mp_beach.dm_60  Absolut-ripley!           5
# 13  224929-WTV-speakeasynet-mp_beach.dm_60        ]+[creamy           5
# 14                      demo0023-ape.dm_60  Wtv-clanbase_Ii           6
# 15    213228-absolutSw33t!8-mp_beach.dm_60    Pr4eferox.nor           6
# 16     GER_vs_ITA_base_fizzel_runde2.dm_60          Caesber           5
# 17     GER_vs_ITA_base_fizzel_runde4.dm_60           Kuebel           5
# 18                225146-MVD-mp_base.dm_60           Tawnos           5
# 19                225146-MVD-mp_base.dm_60            Ses4m           5
# 20                230709-MVD-mp_base.dm_60           Tawnos           5
# 21             POL_LAT_base1_1428720.dm_60           Go_Lat           5
# 22             POL_LAT_base2_1428720.dm_60        Poljendel           5
# 23          POL_LAT_assault1_1428720.dm_60         Polmit0s           5
# 24          POL_LAT_assault1_1428720.dm_60       Polstarsky           5
# 25          POL_LAT_assault2_1428720.dm_60         Polmit0s           5
# 26                       SWE-DEN.APE.dm_60    Absolut_Xtra!           5
#
#                weapons
# 0       5-17-17-17-17-
# 1      17-17-17-17-17-
# 2           7-7-7-7-5-
# 3      46-46-18-18-18-
# 4         5-5-5-18-18-
# 5      17-17-5-5-5-17-
# 6      21-21-21-21-21-
# 7      17-17-17-17-17-
# 8       18-18-18-5-18-
# 9      21-21-21-21-21-
# 10       15-7-7-7-7-5-
# 11          7-7-7-5-5-
# 12          7-7-7-7-7-
# 13         6-7-15-7-7-
# 14  17-17-17-17-17-17-
# 15  17-17-17-17-17-17-
# 16         49-5-5-5-5-
# 17     17-17-46-46-17-
# 18          7-7-5-7-7-
# 19       5-5-17-17-17-
# 20          7-7-7-7-7-
# 21          6-7-7-7-7-
# 22     18-18-18-18-18-
# 23     46-46-46-46-17-
# 24         6-7-7-7-15-
# 25     17-17-46-46-17-
# 26       4-5-17-17-17-

# %%
RTCW.cut_demos(root_path, demos_dct, df_spree, offset_start = 8, offset_end = 8, transform_to_dm_60 = True)
RTCW.generate_capture_list(df_spree, transform_to_dm_60 = True)

# %%
for demo in df_spree.md5:
    for k in demos_dct:
        if demo in demos_dct[k][0]:
            print k
