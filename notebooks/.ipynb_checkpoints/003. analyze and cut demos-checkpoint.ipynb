# %%
import os, sys
import pandas as pd

#import the functions
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import rtcw_functions as RTCW

db_name = 'rtcw_db.db'
demos_folder = 'demos'

cwd = os.getcwd()
demos_path = os.path.join(cwd, '../', demos_folder)

exe_name = 'Anders.Gaming.LibTech3.exe'
demos_folder = 'demos'
root_path = 'C:\\Users\\JelleGrammens\\Documents\\GIT\\rtcw_demo_analyzer' #for executable we need a direct path

# %%
#get demos_dct
demos_dct = RTCW.make_dictionary(demos_path)
# Out:
# parsed 100 matches
# parsed 200 matches
# parsed 300 matches
# parsed 400 matches
# finished parsing all matches!

# %%
#load obituaries in a df
import sqlite3_connector
reload(sqlite3_connector)
db = sqlite3_connector.sqlite3_connector(os.path.join(root_path, db_name))

# %%
obituary_df = db.get_table_as_df(table_name= 'obituary')
player_df = db.get_table_as_df(table_name= 'player')
obituary_df = RTCW.add_match_data(obituary_df, player_df, demos_dct)
obituary_df = obituary_df.loc[obituary_df['League'] == 'ocp2']
# Out:
# obituary table fetched in 0.38 seconds
# player table fetched in 0.04 seconds

# %%
#example, get all 5 man panzerfausts
df_spree = RTCW.get_kill_sprees(obituary_df, 
                                maxtime_secs = 2, 
                                weapon_filter = ['grenade'], 
                                minspree = 3,
                                verbose = True)
# Out:
# scanned 100 demos of 1221 demos in total
# scanned 200 demos of 1221 demos in total
# scanned 300 demos of 1221 demos in total
# scanned 400 demos of 1221 demos in total
# scanned 500 demos of 1221 demos in total
# scanned 600 demos of 1221 demos in total
# scanned 700 demos of 1221 demos in total
# scanned 800 demos of 1221 demos in total
# scanned 900 demos of 1221 demos in total
# scanned 1000 demos of 1221 demos in total
# scanned 1100 demos of 1221 demos in total
# scanned 1200 demos of 1221 demos in total
# all done!

# %%
df_spree
# Out:
#     attacker                                               demo         end  \
# 0          8                                     cohvstfp.dm_59    57117300
# 1          0                                     cohvstfp.dm_59    56654050
# 2          7             Nationscup-Final-Italy-vs-Sweden.dm_60     5639550
# 3          6                       221254-KiHWoLFF-mp_ice.dm_60     2319050
# 4          1                                      tU-rew1.dm_60   102276500
# 5          1                200752-NeonKnightjenl-mp_base.dm_60    51290280
# 6         11                203857-NeonKnightjenl-mp_base.dm_60    52469360
# 7          1  02-17-2002-CAL_7_Empire_Handof_HandofDooM_MP_B...   800419450
# 8          8               BOB_Empire_vs_Krieg_02_28_2002.dm_57    42084600
# 9          9                      003000-agburvear-mp_ice.dm_60    38826450
# 10         8       05-08-03-dt_vs_ds-Base-Bob2_Part_2-WTV.dm_60    53440950
# 11        11               215840-IMMorTAL]NARF[-mp_beach.dm_60    22907100
# 12         6                   003522-[]DeadMeat-mp_beach.dm_60    67800300
# 13         0                 222933-WTV-rtcwno-mp_village.dm_60    59731480
# 14         4                                     demo0001.dm_59    50555500
# 15         6                 214942-UNIQUE-RAMZI-mp_beach.dm_60   332261250
# 16        18                                  ckvsimagine.dm_59    46955000
# 17         7                214734-[187]boogie-mp_village.dm_60    50437400
# 18         6                221224-[187]boogie-mp_village.dm_60    51733200
# 19        13                         224808-[kiz]-mp_base.dm_60   467337300
# 20        15                   222037-raMeSports-mp_beach.dm_60   364652014
# 21         5             dt_vs_narf_cal-m.finals.mp_beach.dm_60     2288850
# 22         8        -a-brian-vs-ds-cal-i-playoffs-village.dm_59    52574550
# 23         2                  174515-4K7Creamy-mp_village.dm_60    93903050
# 24         5                                   mvshf_71_1.dm_59     2710680
# 25         3                       mp_sub-220243-[P]NoOne.dm_59    57714870
# 26         8                223727-FF-0kla-icemat!-mp_ice.dm_60    17403068
# 27        10                        ned_swe_frostbite_wtv.dm_60    56843450
# 28        10  rtcw_2003.06.30_ga-ladder-s3_dot_vs_nurses_fin...     2802200
# 29         9                    215153-kritoso-mp_village.dm_60     4793540
# ..       ...                                                ...         ...
# 31        11                                  ard-in_ice4.dm_60     7566850
# 32         5                    Lem_v_@_eSports_Cup_Beach.dm_60   166466050
# 33         5                          013812-HaVoC-mp_ice.dm_60     6334000
# 34         7                  221827-4K7Creamy-mp_village.dm_60    23069981
# 35         9                  224530-4K7Explicit-mp_beach.dm_60    25165220
# 36         8                212800-[goq'DarkWing]-mp_base.dm_60     6811200
# 37        12         4k_vs_eSports_cbint_17062002_village.dm_59    50277750
# 38         3                     165646-4K7Zommy-mp_beach.dm_60     4938000
# 39        11                                     demo0154.dm_60    41828800
# 40         8                         gmpo-frontline-ice-3.dm_60    14846400
# 41        11                   212019-WTV-rtcwno-mp_beach.dm_60   449516350
# 42         2                  200224-grimdeathHV-mp_beach.dm_60    15970700
# 43         7                              dogma_hfh_vs_or.dm_59    51774000
# 44        12                                       demo_8.dm_57    57148200
# 45         6                                  in-acf_ice1.dm_60   183106046
# 46         2                      mp_sub-173530-drw!$eGUy.dm_59     2176700
# 47        15                                   rew_vs_187.dm_60     5373723
# 48         9                   203504-cKshaftian-mp_beach.dm_60    17605250
# 49        17             233439-[CUP]Veracious-mp_village.dm_59    80819724
# 50        14                                  dsvsdrmatch.dm_57    14323450
# 51         6                                 gZ-de_beach2.dm_60   437190425
# 52         4                  1012528474Flipside79UVWvs86.dm_57    37655650
# 53         9          One_vs_PlanB_eSports_Cup_-_Assault2.dm_60     4854150
# 54         8                         broken-ein-village_1.dm_57   547945100
# 55         1                        212713-32AriCk-mp_ice.dm_60  1377641350
# 56         9             BOB_Empire_vs_Doctors_03_07_2002.dm_57    42025300
# 57        10                 182016-savvaesports-mp_beach.dm_60     2006300
# 58        19                   185747-savvaesports-mp_sub.dm_60     4178150
# 59         6  pM-gpk-communique-1stomdefence_13_35_3mannadez...     1751400
# 60        10                                   udsazeice1.dm_60  1288600072
#
#                                                 match  \
# 0   rtcw_2002.08.13_liga-sw-s1_the-fearless-pigs_v...
# 1   rtcw_2002.08.13_liga-sw-s1_the-fearless-pigs_v...
# 2            rtcw_2003.07.18_cb-nc4_swe_vs_ita_finals
# 3   rtcw_2003.09.14_swertcwcup_rewind_vs_kih_super...
# 4   rtcw_2003.10.13_rtcw.no-premier-s6_rewind_vs_t...
# 5        rtcw_2002.11.28_cb-nc3_ned_vs_aut_groupstage
# 6        rtcw_2002.11.28_cb-nc3_ned_vs_aut_groupstage
# 7   rtcw_2002.02.17_cal-s1_empire_vs_cult-of-hands...
# 8   rtcw_2002.02.28_bob1_empire_vs_krieg_quarter-f...
# 9       rtcw_2003.06.20_qcon03-qual_agb_vs_nde_round1
# 10  rtcw_2003.05.08_bob2_deathtouch_vs_darkside_se...
# 11       rtcw_2003.08.15_qcon03_narf_vs_wsw_wb-round2
# 12  rtcw_2003.07.24_swertcwcup_rewind_vs_gmpo_wb-f...
# 13  rtcw_2003.09.23_rtcw.no-premier-s6_4kings_vs_i...
# 14  rtcw_2002.06.21_qcon02_qual_opp_vs_orange-coun...
# 15   rtcw_2004.09.21_cb-ec10_unique_vs_rtg_groupstage
# 16  rtcw_2002.08.04_cal-m-s3_clan-kapitol_vs_imagi...
# 17               rtcw_2003.01.12_bwl-s2_spooks_vs_187
# 18               rtcw_2003.01.12_bwl-s2_spooks_vs_187
# 19       rtcw_2003.04.23_cb-nc4_ger_vs_ire_groupstage
# 20   rtcw_2002.11.26_esports_infensus_vs_noll8_finals
# 21      rtcw_2003.04.10_cal-m-s4_narf_vs_dt_finals_sc
# 22  rtcw_2002.06.20_cal-i-s2_affliction_vs_darksid...
# 23     rtcw_2003.08.16_qcon03_4kings_vs_wsw_lb-round4
# 24   rtcw_2002.08.16_liga-mp-s2_majesty_vs_heinerfest
# 25  rtcw_2002.10.24_cb-ec6_infensus_vs_exist_group...
# 26       rtcw_2003.09.23_rtcw.no-premier-s6_acf_vs_ff
# 27        rtcw_2004.12.06_cb-nc7_swe_vs_nl_groupstage
# 28  rtcw_2003.06.30_ga-ladder-s3_dot_vs_nurses_finals
# 29       rtcw_2005.04.26_cb-nc8_bel_vs_swe_groupstage
# ..                                                ...
# 31  rtcw_2003.09.23_rtcw.no-premier-s6_infensus_vs...
# 32  rtcw_2002.11.24_esports_amnesia_vs_lemmings_qu...
# 33  rtcw_2003.08.14_qcon03_infensus_vs_dh-us_wb-ro...
# 34  rtcw_2003.05.04_cb-ec7_4kings_vs_snaps_quarter...
# 35  rtcw_2003.05.04_cb-ec7_4kings_vs_snaps_quarter...
# 36  rtcw_2003.10.23_liga-mp-s6_whitesharks_vs_gods...
# 37       rtcw_2002.06.17_cb-ladder_4kings_vs_infensus
# 38  rtcw_2003.08.15_qcon03_4kings_vs_last-chance_l...
# 39   rtcw_2003.04.17_bob2_z_vs_dead-penguin_round2_sc
# 40  rtcw_2003.08.14_qcon03_gmpo_vs_frontline_wb-ro...
# 41   rtcw_2003.09.18_rtcw.no-premier-s6_rewind_vs_acf
# 42        rtcw_2003.08.15_qcon03_gmpo_vs_hv_lb-round1
# 43       rtcw_2002.06.17_qcon02-qual_hfh_vs_or_round1
# 44            rtcw_2002.03.14_cb-ladder_boh_vs_broken
# 45  rtcw_2003.09.16_rtcw.no-premier-s6_acf_vs_infe...
# 46    rtcw_2002.08.16_qcon02_doctors_vs_mtw_wb-round2
# 47    rtcw_2003.02.13_cb-ec7_rewind_vs_187_groupstage
# 48       rtcw_2003.08.15_qcon03_amish_vs_ck_lb-round1
# 49   rtcw_2002.11.07_cb-ec6_euph_vs_radium_groupstage
# 50  rtcw_2002.03.14_bob1_doctors_vs_darkside_final...
# 51  rtcw_2003.09.23_rtcw.no-premier-s6_gz_vs_de.nv...
# 52              rtcw_2002.01.31_bob1_ars_vs_86_round1
# 53  rtcw_2002.11.21_esports_one-soldier_vs_plan-b_...
# 54  rtcw_2002.02.28_cb-cup-spring02_ein_vs_broken_...
# 55  rtcw_2004.09.14_cb-ec10_kreaturen_vs_whoops_qu...
# 56  rtcw_2002.03.07_bob1_doctors_vs_empire_semi-fi...
# 57  rtcw_2002.11.24_esports_infensus_vs_plan-b_qua...
# 58  rtcw_2002.11.24_esports_infensus_vs_plan-b_qua...
# 59                rtcw_2002.02.12_cb-ladder_pm_vs_gpk
# 60     rtcw_2004.12.28_cb-oc-fall04_uds_vs_aze_finals
#
#                                  md5                player  spreecount  \
# 0   59b1f2608f22e9e90e944b36f5929c7c          Tfpred_Baron           4
# 1   59b1f2608f22e9e90e944b36f5929c7c          Coh]i[smoove           3
# 2   4cb47582ec960283ff468286ffa5dcef                In-civ           3
# 3   46a119bff2e2b069f2937d90dca9c654             Kih.wolff           3
# 4   7dcc3ca6fd9b681115de6d7248993356          ][_Negermand           3
# 5   c829f93ae95d6726c5619a7fc82399e1       Neonknightje.nl           3
# 6   c60be2e48e95d37527e3709d526da8b8              Ramzi.nl           3
# 7   73f8cfd9638d111430d22a44fdb7e9cb             Iii-fredo           3
# 8   204e36f690b74c4d0c2d9ed4d6e10756            Iii-vort3x           3
# 9   31d35ed84b474a7a88e979dfacac8fa2        -=nde=-killjoy           3
# 10  9fcf94166a502a6d398524ef9cec040b            Ds-warri0r           3
# 11  f8ac93370ccfa88100bb5ee39b657394            Wswlaws_69           3
# 12  8b0cf51b11ceaaf3d89bdd3f980ff5bd             []_Darkie           3
# 13  e9bd54b06f283c11dc66e93d240e3826         4k^ogdoad_0_o           3
# 14  df27fb786844f289dab5bdba15fac868            [oc]unholy           3
# 15  6a55772ddd1c1342699e89698692ec41           Unique.baba           3
# 16  1603f53511756e632dddb62f4cd74052             ][-r4nd0m           3
# 17  be1bffc8bda9cf1a012c16daa7266f2c      [187]_Pimpniggah           3
# 18  0cf31a9baccba2245bbdfc7c1b1844dc             Oo.madeon           3
# 19  9785b5a54f4c772a4f6a733c2c3d42ea           Painstation           3
# 20  61cb84ad6eb316879889c565a57dc977                O8.ape           3
# 21  5d3fb329dbf49bc6140a69c8dd99e0c3            Da_g]narf[           3
# 22  41eeeed4c596196f5644e9b46a7f2f24              -a-brian           3
# 23  4d9c3417f174aa25b81f47791e528921         Wswevilkiller           3
# 24  a6e4f92a3c55431a41731f83f7c12829             -hf.haze-           3
# 25  81fc34e2eacffc5c18a0834e254e8fcb             [es7'rec]           3
# 26  cb26c7f53225fd0dae7ac38ae6077120     [acf]aimslikeshit           3
# 27  5c7dfec7bb30b78d8099814caca1e3fe             Nl-jehuty           3
# 28  5584b82aa88313dbfc3200de948d974f             .loknlowd           3
# 29  2f71ce0ea7e8cea363a918860f129082              Mayh3m_O           3
# ..                               ...                   ...         ...
# 31  9fec711dcf7afd2e890ad40de03c5660          In-spear_Ypg           3
# 32  a3cb262b702348d3368cf4565b26a0d4            Lem.creamy           3
# 33  3f64ff4c07ad045728e573b175d991ef              .rez0net           3
# 34  2dbbcdd720ac9d3132b4ff002a373960           4k^explicit           3
# 35  0d53107668f4de637ca437cea32a36fe           Snaps'sw33t           3
# 36  a671f52a5eba744ec6f9694629046983        [goq'darkwing]           3
# 37  87d8c06fb00bfbbc73e8dcedd094455c           4k^explicit           3
# 38  3b6ed429d1d083d78fd681c1ec881ff2            4k^hardnut           3
# 39  095dc7e86ced2732a62f2a16187e33ac             Z'prod1gy           3
# 40  6eb4deffbd42698f2db5b1396e906cf0         Gmpoblaze_Amd           3
# 41  60a8cac655a385b77efaf4436d495f66             []_Myst'x           3
# 42  93c659363a59fc47000e84311125b520         Gmporamzi_Amd           3
# 43  0a8d335480f939c89cb75f316a5d8edd              Hfhdogma           3
# 44  35b151d318b03178de5d3ddf7e7fac53        Boh.blindfisch           3
# 45  1754b7fe7f8269730b959884ae4fa5fb          In-zerom_Ypg           3
# 46  7bdd6cf44084a817adc1ef37a2331364            Dr.arkaine           3
# 47  ac248281c2851f5dde4b40e33fbed5a2           I187i_Savva           5
# 48  eb1199ef2785c26cfb45d5bec8954a39            Amish_Seed           3
# 49  f2b659cf9e64cf25243ca3ee5c699999            Chn-radium           3
# 50  edb8efea82067ecff1b07380b0fe1de2              Ds-sh4ms           3
# 51  4272baaf33cfb89b1d4e64934fb5aef8              De'baz_O           3
# 52  70878f3907cae6cfcc70c5d8cdd8c398            [ars]kaeto           3
# 53  3845c5dc39fdaa3eb864126b8a6f1f00          S4b_!_Plan-b           3
# 54  ff13d1a7bc557044504620d914c73875         [broken]skidi           3
# 55  d14fad2a4c5aa60beba5390f3040a674  13_Ozz_Da_Saildorman           3
# 56  92a5e15597eb8276b372f1276c757197             Iii-fredo           3
# 57  cef981065162dbb6b227d9fe967b7a31          N2y_-_Plan-b           3
# 58  b48e99956eddc939418ac0253eda045b         Phil_-_Plan-b           3
# 59  2c97483e3f5d4b79511666b5e0276f2e               Pm][zam           3
# 60  9353bc95d363cfc4b25456a3b76aaa88            Yoda!_#aze           3
#
#          start     weapons
# 0     57117300    5-5-5-5-
# 1     56654050      4-5-5-
# 2      5639550      5-5-5-
# 3      2319050      5-5-5-
# 4    102276500      5-5-5-
# 5     51290280      5-5-5-
# 6     52469360      5-5-5-
# 7    800417600      5-5-5-
# 8     42084600      5-5-5-
# 9     38826450      5-5-5-
# 10    53440950      5-5-5-
# 11    22907100      5-5-5-
# 12    67800300      5-5-5-
# 13    59731480      5-5-5-
# 14    50555500      5-5-5-
# 15   332261250      5-5-5-
# 16    46955000      5-5-5-
# 17    50437400      5-5-5-
# 18    51733200      5-5-5-
# 19   467337300      5-5-5-
# 20   364652014      5-5-5-
# 21     2288850      5-5-5-
# 22    52574550      4-5-5-
# 23    93903050      5-5-5-
# 24     2710680      5-5-5-
# 25    57714870      5-5-5-
# 26    17403068      5-5-5-
# 27    56843450      5-5-5-
# 28     2802200      5-5-5-
# 29     4793540      5-5-5-
# ..         ...         ...
# 31     7566850      5-5-5-
# 32   166466050      5-5-5-
# 33     6332000      5-5-5-
# 34    23069981      5-5-5-
# 35    25165220      5-5-5-
# 36     6811200      5-5-5-
# 37    50277750      5-5-5-
# 38     4938000      5-5-5-
# 39    41828800      5-5-5-
# 40    14846400      5-5-5-
# 41   449516350      5-5-5-
# 42    15970700      5-5-5-
# 43    51774000      5-5-5-
# 44    57148200      5-5-5-
# 45   183106046      5-5-5-
# 46     2176700      5-5-5-
# 47     5373723  5-5-5-5-5-
# 48    17603350      5-5-5-
# 49    80819724      5-5-5-
# 50    14323450      4-5-5-
# 51   437190425      5-5-5-
# 52    37655650      5-5-5-
# 53     4854150      5-5-5-
# 54   547945100      5-5-5-
# 55  1377641350      5-5-5-
# 56    42025300      5-5-5-
# 57     2006300      5-5-5-
# 58     4178150      5-5-5-
# 59     1751400      5-5-5-
# 60  1288600072      5-5-5-
#
# [61 rows x 9 columns]

# %%
RTCW.cut_demos(root_path, demos_dct, df_spree, offset_start = 8, offset_end = 8, transform_to_dm_60 = True)
RTCW.generate_capture_list(df_spree, transform_to_dm_60 = True)

# %%
for demo in df_spree.md5:
    for k in demos_dct:
        if demo in demos_dct[k][0]:
            print k
