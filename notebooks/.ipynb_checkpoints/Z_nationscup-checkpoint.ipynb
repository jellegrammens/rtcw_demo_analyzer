# %%
import os, sys
import pandas as pd

#import the functions
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import rtcw_functions as RTCW
reload(RTCW)

db_name = 'rtcw_db.db'
demos_folder = 'demos'
cwd = os.getcwd()
demos_path = os.path.join(cwd, '../', demos_folder)

exe_name = 'Anders.Gaming.LibTech3.exe'
root_path = 'C:\\Users\\Jelle\\Documents\\GIT\\rtcw_demo_analyzer' #for executable we need a direct path

# %%
#get demos_dct
demos_dct = RTCW.make_dictionary(demos_path)
# Out:
# parsed 100 matches
# parsed 200 matches
# parsed 300 matches
# parsed 400 matches
# finished parsing all matches!

# %%
#load obituaries in a df
import sqlite3_connector
reload(sqlite3_connector)
db = sqlite3_connector.sqlite3_connector(os.path.join(root_path, db_name))

# %%
db.get_table_names()
# Out:
# array(['demo', 'sqlite_sequence', 'chatmessage', 'obituary',
#        'bulletevent', 'player', 'roundstats'], dtype=object)

# %%
obituary_df = db.get_table_as_df(table_name= 'obituary')
demo_df = db.get_table_as_df(table_name= 'demo')
player_df = db.get_table_as_df(table_name= 'player')
roundstats_df = db.get_table_as_df(table_name='roundstats')
bulletevent_df = db.get_table_as_df(table_name='bulletevent')
obituary_df = RTCW.add_match_data(obituary_df, player_df, demos_dct)
obituary_df = obituary_df.loc[obituary_df['League'].isin(['cb-nc6'])]
#obituary_df = obituary_df.loc[obituary_df['League'].isin(['cb-nc3', 'cb-nc4', 'cb-nc5', 'cb-nc6', 'cb-nc7', 'cb-nc8'])]
#obituary_df = obituary_df.loc[obituary_df['Importance'].isin(['lb-round3', 'wb-semi-finals', 'lb-round4'])]

bulletevent_df = RTCW.add_match_data(bulletevent_df, player_df, demos_dct)
chatmessages_df = db.get_table_as_df(table_name= 'chatmessage')
chatmessages_df = RTCW.add_match_data(chatmessages_df, player_df, demos_dct, what_df = 'chatmessages_df')
chatmessages_df = RTCW.feature_extraction_chat(chatmessages_df)
# Out:
# obituary table fetched in 0.48 seconds
# demo table fetched in 0.03 seconds
# player table fetched in 0.06 seconds
# roundstats table fetched in 0.07 seconds
# bulletevent table fetched in 0.96 seconds
# chatmessage table fetched in 0.86 seconds

# %%
df_spree = RTCW.get_kill_sprees(obituary_df, 
                                demo_df,
                                maxtime_secs = 100, 
                                include_weapon_filter = ['smg'],
                                exclude_weapon_filter = None, 
                                minspree = 3,
                                pov_sprees_only = False,
                                verbose = True)
# Out:
# all done!

# %%
df_spree[['match', 'demo', 'player', 'spreecount', 'weapons', 'attacker', 'pov_id']].sort_values('spreecount', ascending=False)
# Out:
#                                               match  \
# 230  rtcw_2004.04.15_cb-nc6_ger_vs_spain_groupstage
# 208    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 115     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 183    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 96      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 147    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 196    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 117     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 26     rtcw_2004.06.08_cb-nc6_nl_vs_swe_semi-finals
# 131     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 28     rtcw_2004.06.08_cb-nc6_nl_vs_swe_semi-finals
# 189    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 248  rtcw_2004.04.15_cb-nc6_ger_vs_spain_groupstage
# 37     rtcw_2004.06.08_cb-nc6_nl_vs_swe_semi-finals
# 100     rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 184    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 94      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 59     rtcw_2004.06.08_cb-nc6_nl_vs_swe_semi-finals
# 86      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 220  rtcw_2004.04.15_cb-nc6_ger_vs_spain_groupstage
# 221  rtcw_2004.04.15_cb-nc6_ger_vs_spain_groupstage
# 69      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 187    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 75      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 178    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 137     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 167    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 3      rtcw_2004.06.08_cb-nc6_nl_vs_swe_semi-finals
# 168    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 22     rtcw_2004.06.08_cb-nc6_nl_vs_swe_semi-finals
# ..                                              ...
# 159    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 160    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 161    rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 125     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 124     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 123     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 101     rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 85      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 87      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 88      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 90      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 91      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 92      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 93      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 97      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 98      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 99      rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 103     rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 122     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 104     rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 107     rtcw_2004.04.25_cb-nc6_swe_vs_nl_groupstage
# 110     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 112     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 113     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 114     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 116     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 119     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 120     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 121     rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 270  rtcw_2004.04.15_cb-nc6_ger_vs_spain_groupstage
#
#                                   demo           player  spreecount  \
# 230     223014-eS-enrGy!-mp_base.dm_60             Spx!           7
# 208    215434-framote-mp_village.dm_60             Spx!           7
# 115      212247-sE-SoD!-mp_beach.dm_60           Se-civ           7
# 183      212327-framote-mp_beach.dm_60             Cris           6
# 96          220810-sE-civ-mp_ice.dm_60       Nl-element           6
# 147      210759-frapit!-mp_beach.dm_60         Fra_Mote           6
# 196    215434-framote-mp_village.dm_60             We4k           5
# 117      212247-sE-SoD!-mp_beach.dm_60          Se-sod!           5
# 26      nl_vs_sweden3-mp_village.dm_60        Se-summ3l           5
# 131    220057-sE-wuff-mp_village.dm_60  Gs-civ(gummans)           5
# 28      nl_vs_sweden3-mp_village.dm_60        Nl-kezza!           5
# 189  215004-frabandit-mp_village.dm_60             We4k           5
# 248        225402-eS-frEe-mp_ice.dm_60         Alp3nb0g           5
# 37      nl_vs_sweden3-mp_village.dm_60      Se-turnrosa           5
# 100         220810-sE-civ-mp_ice.dm_60        Nl-jehuty           5
# 184      212327-framote-mp_beach.dm_60             Cris           5
# 94          220810-sE-civ-mp_ice.dm_60      Se-turnrosa           5
# 59         nl_vs_sweden-MP_BEACH.dm_60           Se-civ           5
# 86          220810-sE-civ-mp_ice.dm_60        Se-hombre           5
# 220     223014-eS-enrGy!-mp_base.dm_60         Alp3nb0g           5
# 221     223014-eS-enrGy!-mp_base.dm_60         Alp3nb0g           5
# 69      212613-sE-civ-mp_assault.dm_60        Se-hombre           5
# 187  215004-frabandit-mp_village.dm_60            Sp!k3           5
# 75      214130-sE-civ-mp_assault.dm_60      Se-turnrosa           5
# 178      212327-framote-mp_beach.dm_60         Fra_Mote           5
# 137    220057-sE-wuff-mp_village.dm_60         Se-spear           5
# 167      212327-framote-mp_beach.dm_60          Dr4goon           5
# 3       nl_vs_sweden1-mp_village.dm_60      Se-turnrosa           5
# 168      212327-framote-mp_beach.dm_60          Dr4goon           5
# 22      nl_vs_sweden3-mp_village.dm_60          Se-sod!           5
# ..                                 ...              ...         ...
# 159      210759-frapit!-mp_beach.dm_60             Cris           3
# 160      210759-frapit!-mp_beach.dm_60             We4k           3
# 161      210759-frapit!-mp_beach.dm_60             We4k           3
# 125     214534-uk-decay-mp_beach.dm_60       Se-hombre,           3
# 125              17-17-17-         7      11
# 124              17-17-17-         7      11
# 123              18-18-18-         5      11
# 101              18-18-18-         6      10
# 85               18-18-18-         6      10
# 87               17-17-17-         2      10
# 88               17-17-17-         2      10
# 90               18-18-18-         8      10
# 91               18-18-18-         8      10
# 92               17-17-17-         8      10
# 93               18-18-18-         7      10
# 97               18-18-18-        14      10
# 98               17-17-17-        11      10
# 99               17-17-17-        11      10
# 103              17-17-17-         4      10
# 122              17-17-17-        12      11
# 104              17-17-17-         4      10
# 107              17-17-17-         9      10
# 110              17-17-17-         7      11
# 112              17-17-17-         4      11
# 113              17-17-17-         4      11
# 114              18-18-18-         6      11
# 116              17-17-17-         8      11
# 119              17-17-17-         5      11
# 120              17-17-17-         1      11
# 121              18-18-18-         8      11
# 270              18-18-18-        14       9
#
# [271 rows x 7 columns]

# %%
demos_dct['rtcw_2003.08.16_qcon03_gmpo_vs_infensus_grand-finals_sc']
# Out:
# [['26ae8790bc46f7491ca89f29332303f1'], ['demo-qcon2k3finals.dm_60']]

# %%
obituary_df = db.get_table_as_df(table_name= 'obituary')
# Out:
# obituary table fetched in 1.02 seconds

# %%
obituary_df[obituary_df['szMd5'] == 'rtcw_2003.08.16_qcon03_gmpo_vs_infensus_grand-finals_sc']
# Out:
# Empty DataFrame
# Columns: [dwSeq, szMd5, bAttacker, bTarget, bWeapon, dwTime, bIsTeamkill, szTimeString, szMessage]
# Index: []

# %%
obituary_df[obituary_df['szMd5'] == '26ae8790bc46f7491ca89f29332303f1']
# Out:
#        dwSeq                             szMd5  bAttacker  bTarget  bWeapon  \
# 71547  71548  26ae8790bc46f7491ca89f29332303f1         14       14       56
# 71548  71549  26ae8790bc46f7491ca89f29332303f1         10       10       56
# 71549  71550  26ae8790bc46f7491ca89f29332303f1          7        7       56
# 71550  71551  26ae8790bc46f7491ca89f29332303f1         12        3       21
# 71551  71552  26ae8790bc46f7491ca89f29332303f1          4        4       56
# 71552  71553  26ae8790bc46f7491ca89f29332303f1         11        2       21
# 71553  71554  26ae8790bc46f7491ca89f29332303f1          8       14       17
# 71554  71555  26ae8790bc46f7491ca89f29332303f1         12        2       21
# 71555  71556  26ae8790bc46f7491ca89f29332303f1          3        7       18
# 71556  71557  26ae8790bc46f7491ca89f29332303f1          4       10        7
# 71557  71558  26ae8790bc46f7491ca89f29332303f1         13        4       21
# 71558  71559  26ae8790bc46f7491ca89f29332303f1         13       13       56
# 71559  71560  26ae8790bc46f7491ca89f29332303f1          7        7       56
# 71560  71561  26ae8790bc46f7491ca89f29332303f1          2       11       21
# 71561  71562  26ae8790bc46f7491ca89f29332303f1         12        2       21
# 71562  71563  26ae8790bc46f7491ca89f29332303f1          8       13       17
# 71563  71564  26ae8790bc46f7491ca89f29332303f1         12        2       21
# 71564  71565  26ae8790bc46f7491ca89f29332303f1        254        7       55
# 71565  71566  26ae8790bc46f7491ca89f29332303f1          3        3       56
# 71566  71567  26ae8790bc46f7491ca89f29332303f1         12        9       21
# 71567  71568  26ae8790bc46f7491ca89f29332303f1         14       14       56
# 71558  2232100            1         9:10
# 71559  2232350            1         9:10
# 71560  2236350            0         9:06
# 71561  2237900            0         9:04
# 71562  2239200            0         9:03
# 71563  2245100            0         8:57
# 71564  2245800            0         8:56
# 71565  2247550            1         8:54
# 71566  2262350            0         8:40
# 71567  2262550            1         8:39
# 71568  2262900            1         8:39
# 71569  2274150            0         8:28
# 71570  2274750            0         8:27
# 71571  2282000            0         8:20
# 71572  2284350            0         8:18
# 71573  2288800            1         8:13
# 71574  2289000            1         8:13
# 71575  2292200            1         8:10
# 71576  2300600            0         8:01
# ...        ...          ...          ...
# 72086  5293700            1         2:37
# 72087  5300000            0         2:30
# 72088  5300900            0         2:30
# 72089  5311200            0         2:19
# 72090  5315900            0         2:15
# 72091  5321250            0         2:09
# 72092  5321250            1         2:09
# 72093  5324200            0         2:06
# 72094  5326750            0         2:04
# 72095  5327350            0         2:03
# 72096  5331150            0         1:59
# 72097  5334650            1         1:56
# 72098  5353900            0         1:37
# 72099  5358050            0         1:32
# 72100  5364750            0         1:26
# 72101  5367950            0         1:22
# 72102  5369100            0         1:21
# 72103  5373600            0         1:17
# 72104  5375300            1         1:15
# 72105  5378200            0         1:12
# 72106  5378200            0         1:12
# 72107  5385950            0         1:04
# 72108  5396050            0         0:54
# 72109  5396850            0         0:54
# 72110  5399650            0         0:51
# 72111  5405000            0         0:45
# 72112  5410550            0         0:40
# 72113  5415450            1         0:35
# 72114  5422150            0         0:28
# 72115  5446000            1         0:04
#
#                                                szMessage
# 71547                     GMPOREFUSE AMD killed himself.
# 71548                     GMPOZEMME  AMD killed himself.
# 71549                     GMPOZAF'   AMD killed himself.
# 71550  iN-HoMBre was killed by GMPOVERAC  AMD's snipe...
# 71551                          iN-Spear? killed himself.
# 71552  iN-civ was killed by GMPOBLAZE  AMD's sniper r...
# 71553        GMPOREFUSE AMD was killed by iN-wizz's MP40
# 71554  iN-civ was killed by GMPOVERAC  AMD's sniper r...
# 71555  GMPOZAF'   AMD was killed by iN-HoMBre's Thompson
# 71556  GMPOZEMME  AMD was blasted by iN-Spear?'s Panz...
# 71557  iN-Spear? was killed by GMPORAMZI  AMD's snipe...
# 71558                     GMPORAMZI  AMD killed himself.
# 71559                     GMPOZAF'   AMD killed himself.
# 71560  GMPOBLAZE  AMD was killed by iN-civ's sniper r...
# 71561  iN-civ was killed by GMPOVERAC  AMD's sniper r...
# 71562        GMPORAMZI  AMD was killed by iN-wizz's MP40
# 71563  iN-civ was killed by GMPOVERAC  AMD's sniper r...
# 71564                  GMPOZAF'   AMD fell to his death.
# 71565                          iN-HoMBre killed himself.
# 71566  iN-SoD! was killed by GMPOVERAC  AMD's sniper ...
# 71567                     GMPOREFUSE AMD killed himself.
# 71568                     GMPOZEMME  AMD killed himself.
# 71569             GMPOZAF'   AMD was killed by iN-HoMBre
# 71570  GMPOBLAZE  AMD was killed by iN-civ's sniper r...
# 71571      GMPOREFUSE AMD was killed by iN-Spear?'s MP40
# 71572        GMPOZEMME  AMD was killed by iN-wizz's MP40
# 71573                          iN-Spear? killed himself.
# 71574                          iN-HoMBre killed himself.
# 71575                     GMPOVERAC  AMD killed himself.
# 71576  GMPOVERAC  AMD was killed by iN-civ's sniper r...
# ...                                                  ...
# 72086                          iN-HoMBre killed himself.
# 72087  GMPOBLAZE  AMD was blasted by iN-Spear?'s Panz...
# 72088  GMPOVERAC  AMD was killed by iN-civ's sniper r...
# 72089  GMPOZEMME  AMD was killed by iN-civ's sniper r...
# 72090      GMPOZAF'   AMD was killed by iN-HoMBre's MP40
# 72091  GMPORAMZI  AMD was blasted by iN-Spear?'s Panz...
# 72092                       iN-Spear? vaporized himself.
# 72093        GMPOREFUSE AMD was killed by iN-wizz's MP40
# 72094  GMPOVERAC  AMD was killed by iN-civ's sniper r...
# 72095        iN-wizz was killed by GMPOBLAZE  AMD's MP40
# 72096  GMPOZEMME  AMD was killed by iN-civ's sniper r...
# 72097                          iN-HoMBre killed himself.
# 72098      GMPOZAF'   AMD was killed by iN-Spear?'s MP40
# 72099      iN-HoMBre was killed by GMPORAMZI  AMD's MP40
# 72100      iN-Spear? was killed by GMPORAMZI  AMD's MP40
# 72101  GMPOBLAZE  AMD was killed by iN-civ's sniper r...
# 72102             GMPOZAF'   AMD was killed by iN-Spear?
# 72103             GMPOREFUSE AMD was killed by iN-Spear?
# 72104                             iN-civ killed himself.
# 72105  GMPOBLAZE  AMD was blasted by iN-wizz's suppor...
# 72106  GMPORAMZI  AMD was blasted by iN-wizz's suppor...
# 72107      GMPOZAF'   AMD was killed by iN-HoMBre's MP40
# 72108      iN-HoMBre was killed by GMPOREFUSE AMD's MP40
# 72109  GMPOVERAC  AMD was killed by iN-Summ3L's Thompson
# 72110        iN-wizz was killed by GMPOZEMME  AMD's MP40
# 72111  GMPOREFUSE AMD was killed by iN-civ's sniper r...
# 72112  GMPOZEMME  AMD was killed by iN-civ's sniper r...
# 72113                          iN-Spear? killed himself.
# 72114  GMPOREFUSE AMD was killed by iN-civ's sniper r...
# 72115  GMPOZAF'   AMD was killed by GMPOZEMME  AMD's ...
#
# [569 rows x 9 columns]

# %%
RTCW.cut_demos(root_path, demos_dct, df_spree, offset_start = 8, offset_end = 8, transform_to_dm_60 = True, demo_folder_name= 'demos')
RTCW.generate_capture_list(df_spree,  transform_to_dm_60 = True)

# %%
for demo in df_spree.md5:
    for k in demos_dct:
        if demo in demos_dct[k][0]:
            print k

# %%
docs_df = RTCW.get_docruns(chatmessages_df, min_docrun_length = 10, max_timeleft = 30, docs_succesful = True, min_docs_lost = 0, verbose = True)

# %%
save_index = docs_df[['start', 'end', 'start_secsleft', 'end_secsleft', 'duration', 'times_lost_docs', 'won_round']].drop_duplicates().index
docs_df = docs_df[docs_df.index.isin(save_index)]

# %%
docs_df[['match','start', 'end', 'start_secsleft', 'end_secsleft', 'duration', 'times_lost_docs', 'won_round']]

# %%
reload(RTCW)
RTCW.cut_demos(root_path, demos_dct, docs_df, demo_type = 'docs', offset_start = 8, offset_end = 8, transform_to_dm_60 = True, demo_folder_name= 'demos')

# %%
RTCW.generate_capture_list(docs_df, demo_type='docs', transform_to_dm_60 = True)
