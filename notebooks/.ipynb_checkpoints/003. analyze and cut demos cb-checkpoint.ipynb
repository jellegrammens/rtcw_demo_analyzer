# %%
import os, sys
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

#import the functions
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import rtcw_functions as RTCW
reload(RTCW)

db_name = 'cb.db'
demos_folder = 'demoscb'

cwd = os.getcwd()
demos_path = os.path.join(cwd, '../', demos_folder)

exe_name = 'Anders.Gaming.LibTech3.exe'
root_path = 'C:\\Users\\Jelle\\Documents\\GIT\\rtcw_demo_analyzer' #for executable we need a direct path

# %%
#get demos_dct
demos_dct = RTCW.make_dictionary(demos_path)
# Out:
# parsed 100 matches
# finished parsing all matches!

# %%
#load obituaries in a df
import sqlite3_connector
db = sqlite3_connector.sqlite3_connector(os.path.join(root_path, db_name))

obituary_df = db.get_table_as_df(table_name= 'obituary')
demo_df = db.get_table_as_df(table_name= 'demo')
player_df = db.get_table_as_df(table_name= 'player')
obituary_df = RTCW.add_match_data(obituary_df, player_df, demos_dct)
bulletevent_df = db.get_table_as_df(table_name= 'bulletevent')
bulletevent_df = RTCW.add_match_data(bulletevent_df, player_df, demos_dct)
chatmessages_df = db.get_table_as_df(table_name= 'chatmessage')
chatmessages_df = RTCW.add_match_data(chatmessages_df, player_df, demos_dct, what_df = 'chatmessages_df')
chatmessages_df = RTCW.feature_extraction_chat(chatmessages_df)
# Out:
# obituary table fetched in 0.2 seconds
# demo table fetched in 0.01 seconds
# player table fetched in 0.02 seconds
# bulletevent table fetched in 0.42 seconds
# chatmessage table fetched in 0.27 seconds

# %%
bulletevent_df = bulletevent_df[bulletevent_df['szMd5'] == 'b9d0918f6ec71fcb5e3756363c75a569']
bulletevent_df_backup = bulletevent_df.copy()

# %%
# obituary_df = obituary_df[obituary_df['matchName'] == 'rtcw_2005.05.02_cb-nc8_uk_vs_nl_groupstage']
# obituary_df = obituary_df[obituary_df['szCleanName'] == 'NL-lus3D^^']
# obits = obituary_df.iloc[[5]]

# %%
df_spree = RTCW.get_kill_sprees(obits, 
                                demo_df,
                                maxtime_secs = 1, 
                                include_weapon_filter = None,
                                exclude_weapon_filter = None, 
                                minspree = 1,
                                pov_sprees_only = False,
                                verbose = True)

df_spree[['match', 'demo', 'player', 'spreecount', 'weapons']]

# %%
RTCW.cut_demos(root_path, demos_dct, df_spree, offset_start = 8, offset_end = 40, transform_to_dm_60 = True, demo_folder_name = demos_folder)
RTCW.generate_capture_list(df_spree, transform_to_dm_60 = True)

# %%
res = RTCW.get_docruns(chatmessages_df, 
                       min_docrun_length = 10, 
                       max_timeleft = 30, 
                       docs_succesful = None, 
                       min_docs_lost = 2, 
                       verbose = True)
res[['start', 'end', 'start_secsleft', 'end_secsleft', 'duration', 'times_lost_docs', 'won_round', 'md5']]

# %%
RTCW.cut_demos(root_path, demos_dct, res, demo_type = 'docs', offset_start = 8, offset_end = 8, transform_to_dm_60 = True, demo_folder_name = demos_folder)
RTCW.generate_capture_list(res, demo_type='docs', transform_to_dm_60 = True)

# %%
df_wtv = RTCW.get_wtvmoments(chatmessages_df, z = 7, window = 10, verbose=True)
df_wtv

# %%
RTCW.cut_demos(root_path, demos_dct, df_wtv, demo_type = 'wtv', offset_start = 15, offset_end = 8, transform_to_dm_60 = True, demo_folder_name= 'demos')
RTCW.generate_capture_list(df_wtv, demo_type='wtv', transform_to_dm_60 = True)

# %%
df_hs = RTCW.get_headshot_sprees(bulletevent_df, demo_df, maxtime_secs = 1, minspree = 5)
df_hs
# Out:
# scanned 100 demos of 366 demos in total
# scanned 200 demos of 366 demos in total
# scanned 300 demos of 366 demos in total
# all done!
#     attacker                                         demo         end  \
# 0         12                  210655-Bully-mp_beach.dm_60     1682193
# 1          4                       inf-apeVSinverse.dm_60    10513675
# 2          4                       inf-apeVSinverse.dm_60    10873075
# 3          3                       inf-apeVSinverse.dm_60    11620125
# 4          3        223407-finIveracious-mp_village.dm_60   869878004
# 5          9        223407-finIveracious-mp_village.dm_60   869731484
# 6         14              221928-gmpowuffAMD-mp_ice.dm_60  1417597550
# 7         11                 224429-Stinger-mp_base.dm_60   264643900
# 8         11             210300-uk-crmbs-mp_village.dm_60   604389144
# 9          6             210300-uk-crmbs-mp_village.dm_60   604657344
# 10        12               224519-iN-zam-mp_village.dm_60   159107309
# 11        11               224519-iN-zam-mp_village.dm_60   159990958
# 12         4         214220-WTV-ClanBase-mp_village.dm_60     4530690
# 13         1              220057-sE-wuff-mp_village.dm_60    16017950
# 14        10  EST_NOR_ice_wtv_3998439-quarterfinals.dm_60    55155450
# 15        10            222726-[+]CapteN-mp_assault.dm_60    60032500
# 16         9              220022-WTV-TnX-mp_village.dm_60   384943350
# 17         3             214231-[]Darkie-mp_village.dm_60   359409750
# 18         3             214231-[]Darkie-mp_village.dm_60   359542550
# 19         9             nl-vs-belgium-de_frostbite.dm_60   466377850
# 20        14                212327-framote-mp_beach.dm_60   856094429
# 21         4              221055-Fro$t-de_frostbite.dm_60      405200
# 22        17                   224808-[kiz]-mp_base.dm_60   467107150
# 23         7                    EYE_vs_SnapS_EC_WTV.dm_60   437730243
# 24        10                             kodvspimps.dm_60     6011850
# 25        10      211251-WTV-team-itacom-mp_village.dm_60    54664700
# 26         9      pol_bel_mp_village1_chase_1879964.dm_60   125664511
# 27         5                201740-treff-mp_village.dm_60    57017550
# 28         2                201740-treff-mp_village.dm_60    56396400
#
#                                                 match  \
# 0        rtcw_2003.04.18_cb-nc4_ger_vs_aut_groupstage
# 1   rtcw_2003.05.13_cb-oc-spring03_infront_vs_inve...
# 2   rtcw_2003.05.13_cb-oc-spring03_infront_vs_inve...
# 3   rtcw_2003.05.13_cb-oc-spring03_infront_vs_inve...
# 4       rtcw_2003.01.26_cb-nc3_ger_vs_fin_semi-finals
# 5       rtcw_2003.01.26_cb-nc3_ger_vs_fin_semi-finals
# 6   rtcw_2003.11.23_cb-ec8_kreaturen_vs_gmpo_semi-...
# 7        rtcw_2003.05.11_cb-nc4_ger_vs_esp_groupstage
# 8          rtcw_2005.05.02_cb-nc8_uk_vs_nl_groupstage
# 9          rtcw_2005.05.02_cb-nc8_uk_vs_nl_groupstage
# 10  rtcw_2002.12.05_cb-ec6_infensus_vs_4kings_semi...
# 11  rtcw_2002.12.05_cb-ec6_infensus_vs_4kings_semi...
# 12       rtcw_2005.04.26_cb-nc8_bel_vs_swe_groupstage
# 13        rtcw_2004.04.07_cb-nc6_swe_vs_uk_groupstage
# 14   rtcw_2005.01.12_cb-nc7_est_vs_nor_quarter-finals
# 15       rtcw_2003.04.27_cb-nc4_swe_vs_ita_groupstage
# 16           rtcw_2003.02.09_cb-nc3_swe_vs_fin_finals
# 17  rtcw_2003.04.03_cb-ec7_rewind_vs_apical_groups...
# 18  rtcw_2003.04.03_cb-ec7_rewind_vs_apical_groups...
# 19            rtcw_2004.06.18_cb-nc6_bel_vs_nl_finals
# 20       rtcw_2004.04.11_cb-nc6_ger_vs_fra_groupstage
# 21       rtcw_2004.12.07_cb-nc7_bel_vs_fra_groupstage
# 22       rtcw_2003.04.23_cb-nc4_ger_vs_ire_groupstage
# 23  rtcw_2003.02.24_cb-ec7_snaps_vs_eye-(former-18...
# 24   rtcw_2003.12.19_cb-oc-fall03_kod_vs_pimps_finals
# 25      rtcw_2003.07.09_cb-nc4_ita_vs_ned_semi-finals
# 26       rtcw_2003.04.17_cb-nc4_bel_vs_pol_groupstage
# 27            rtcw_2005.07.31_cb-nc8_uk_vs_ger_finals
# 28            rtcw_2005.07.31_cb-nc8_uk_vs_ger_finals
#
#                                  md5           player  pov_id  spreecount  \
# 0   31517ca9dfccabf92bc11d5c4355a3cd           Reaper       4           5
# 1   c586654f52c9355d852e81d795d1d1c0       [inf]_Zap!      11           5
# 2   c586654f52c9355d852e81d795d1d1c0       [inf]_Zap!      11           5
# 3   c586654f52c9355d852e81d795d1d1c0        Hz-savage      11           7
# 4   bf282058eb840ba253d9ef4410807be1     Finisanctity       2           5
# 5   bf282058eb840ba253d9ef4410807be1           Kuebel       2           7
# 6   b3389bc927fcebaef69388d9bc7c1159       Iki_Doekoe       2           5
# 7   64d0c9593c77466ae7d52efb4f51afce          Stinger      11           5
# 8   f3155093dd9b370d0671fa22a277c4d7       Nl-flits!.       0           5
# 9   f3155093dd9b370d0671fa22a277c4d7       Nl-lus3d^^       0           7
# 10  1c58721ff9b10bde809f5ccb65453faf        In-summ3l       6           5
# 11  1c58721ff9b10bde809f5ccb65453faf           4k^cjm       6           5
# 12  691f23ba7715e83b5632e16b2bec3d1e         Smutz.se       1           5
# 13  fd21257b46a33971d2c17cd29a6b404c         Se-spear      11           5
# 14  15653ead1e6da8ce01af6ad0d7b839a9       Eesti_Rene       9           5
# 15  9262280e64b91f58d35a24b49f08bfd4        [+]_Alban       7           5
# 16  db8fcd31f9703deee3c3dd35be751092  Absolut_Summ3l!      63           5
# 17  30513b3f89a0aa8ba0de099bf466a30c      []_Deadmeat      63           7
# 18  30513b3f89a0aa8ba0de099bf466a30c      []_Deadmeat      63           5
# 19  8c86044e8cea9a31f13058602d504bd4        Nl-jehuty       7           5
# 20  4b3e74331296cce21c30631f18441726             Spx!       5           5
# 21  b9d0918f6ec71fcb5e3756363c75a569          Dav1d_O      12           5
# 22  9785b5a54f4c772a4f6a733c2c3d42ea          Caesber      63           6
# 23  fa3c0373a7bc491bd32996b6db3c5b35     Snaps'capten      63           5
# 24  ac77545f6baf080f914e536e1800398d     Kod.janciper       1           5
# 25  8d27d480ee5febe24d74761d937f5640            O.s4n      63           7
# 26  8f8ec4cb6c5aa78c821c28193141cde7            Syl_O      11           5
# 27  18522ce490a3f5bfb86cb30ff2928669         Uk-creed      15           5
# 28  18522ce490a3f5bfb86cb30ff2928669         Uk-crmbs      15           5
#
#          start
# 0      1681434
# 1     10513125
# 2     10872525
# 3     11619175
# 4    869877080
# 5    869730758
# 6   1417596650
# 7    264643200
# 8    604388194
# 9    604656594
# 10   159106880
# 11   159990562
# 12     4530290
# 13    16017100
# 14    55154650
# 15    60031950
# 16   384942850
# 17   359408950
# 18   359541650
# 19   466377350
# 20   856093829
# 21      404700
# 22   467106150
# 23   437729649
# 24     6010900
# 25    54664100
# 26   125663785
# 27    57016650
# 28    56395550

# %%
reload(RTCW)
RTCW.cut_demos(root_path, demos_dct, df_hs, demo_type = 'hs', offset_start = 8, offset_end = 2, transform_to_dm_60 = True, demo_folder_name = demos_folder)
RTCW.generate_capture_list(df_hs, demo_type='hs', transform_to_dm_60 = True)
