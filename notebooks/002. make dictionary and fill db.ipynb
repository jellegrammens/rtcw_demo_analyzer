# %%
#make path strings needed for script to run
import os, sys
import numpy as np
import pandas as pd
import hashlib
path = os.getcwd()
exe_name = 'Anders.Gaming.LibTech3.exe'
demos_folder = 'demos'
root_path = 'C:\\Users\\Jelle\\Documents\\GIT\\rtcw_demo_analyzer' #for executable we need a direct path
exe_path = os.path.join(path, '../', exe_name)
demos_path = os.path.join(path, '../', demos_folder)

#import the functions
module_path = os.path.abspath(os.path.join('../src/'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
import rtcw_functions as RTCW
reload(RTCW)
# Out:
# <module 'rtcw_functions' from 'C:\Users\Jelle\Documents\GIT\rtcw_demo_analyzer\src\rtcw_functions.pyc'>

# %%
# make dictionary with:
# key = 1 match folder
# value = list with md5 checksum + list with demo names (ordered by play time)
demos_dct = RTCW.make_dictionary(demos_path)
# Out:
# parsed 100 matches
# parsed 200 matches
# parsed 300 matches
# parsed 400 matches
# finished parsing all matches!

# %%
#dct with string parameters for anders lib tech3 api indexer parameters
parameters_dct = {}
parameters_dct['exportPaths'] = root_path
parameters_dct['exportBulletEvents'] = '0'
parameters_dct['exportPlayers'] = '1'
parameters_dct['exportDemo'] = '1'
parameters_dct['exportObituaries'] = '1'
parameters_dct['exportChatMessages'] = '1'
parameters_dct['exportJson'] = '0'
parameters_dct['exportSQL'] = '1'
parameters_dct['eportJsonFile'] = 'out.json'
parameters_dct['exportSQLFile'] = 'demo_db.db'

# %%
#input all demos from demos folders 
RTCW.fill_db(root_path, parameters_dct, demos_dct)
# Out:
# 1055818784d@n!el-mp_ice.dm_60
# SM-Ligan_Merge-SWF_POV_s3VVi_Beach.dm_60
# cohvstfp.dm_59
# 043942-grimdeathHV-mp_ice.dm_60
# 045124-silenceHV-mp_ice.dm_60
# 050920-silentstormHV-mp_ice.dm_60
# 210638-WTV-@rtcw-ligade-mp_assault.dm_60
# 211803-KoDAndi-mp_assault.dm_60
# 212535-WTV-@rtcw-ligade-mp_assault.dm_60
# 213215-]GaB-aSSa[-mp_assault.dm_60
# 213853-KoDg1zzY-mp_assault.dm_60
# 214629-WTV-@rtcw-ligade-mp_assault.dm_60
# 215435-WTV-@rtcw-ligade-mp_assault.dm_60
# 220429-KoDJanCiper-mp_assault.dm_60
# 221421-WTV-@rtcw-ligade-mp_assault.dm_60
# 222334-WTV-@rtcw-ligade-mp_assault.dm_60
# OcrvEuph_eSports_Cup_Beach1.dm_60
# OcrvEuph_eSports_Cup_Beach2.dm_60
# OcrvEuph_eSports_Cup_Ice.dm_60
# 230748-AmishmadE-mp_base.dm_60
# 231319-AmishmadE-mp_base.dm_60
# 231835-AmishmadE-mp_base.dm_60
# 232710-AmishmadE-mp_base.dm_60
# 233104-AmishmadE-mp_base.dm_60
# 233914-AmishmadE-mp_base.dm_60
# 234315-AmishmadE-mp_base.dm_60
# 234640-AmishmadE-mp_base.dm_60
# 210447-a-L'kuraiguMSI-mp_base.dm_60
# 210929-iN-zerom-mp_base.dm_60
# 211320-a-L'kuraiguMSI-mp_base.dm_60
# cscvsrr.dm_60
# 211136-rWDStork-mp_ice.dm_60
# 214110-rWDStork-mp_ice.dm_60
# 220526-rWDStork-mp_ice.dm_60
# 222136-rWDStork-mp_ice.dm_60
# 223431-rWDStork-mp_ice.dm_60
# 224528-rWDStork-mp_ice.dm_60
# 221740-WFL'Admin'Sengo-mp_base.dm_60
# 223530-WFL'Admin'Sengo-mp_base.dm_60
# 223922-WFL'Admin'Sengo-mp_base.dm_60
# 224211-WFL'Admin'Sengo-mp_base.dm_60
# 222046-iN-civ-mp_ice.dm_60
# 225237-iN-civ-mp_village.dm_60
# 180257-Da_G]NARF[-mp_sub.dm_60
# 180711-Da_G]NARF[-mp_sub.dm_60
# 181238-Da_G]NARF[-mp_sub.dm_60
# 181848-Da_G]NARF[-mp_sub.dm_60
# 182606-Da_G]NARF[-mp_sub.dm_60
# Nationscup-Final-Italy-vs-Sweden.dm_60
# iN_vs_Abuse_beach.dm_59
# rtcwl-sw1-rr-planb-mp_chateau.dm_59
# 1012539750Demo_00.dm_57
# darkside-cK_calrtcwi-mp_assault_povjones.dm_58
# 02-14-2002-bob-empire-vs-da-village-214021-round3.dm_57
# 215524-[]RaZiel-mp_ice.dm_60
# 221254-KiHWoLFF-mp_ice.dm_60
# 222745-[]Darkie-mp_ice.dm_60
# pM-DON-assault_cb.dm_57
# pM-DON-communique_cb.dm_57
# rtcw_2003.01.16_ga-ladder-s2_dot_vs_se_finals.dm_60
# tU-rew1.dm_60
# tU-rew2.dm_60
# tU-rew3.dm_60
# tU-rew4.dm_60
# tU-rew5.dm_60
# tU-rew6.dm_60
# tU-rew7.dm_60
# tU-rew8.dm_60
# 203603-rTgSp!k3-mp_village.dm_60
# 205829-rTgSp!k3-mp_village.dm_60
# 210651-rTgSp!k3-mp_village.dm_60
# 212026-rTgSp!k3-mp_village.dm_60
# 215031-rTgSp!k3-mp_village.dm_60
# 200752-NeonKnightjenl-mp_base.dm_60
# 202410-NeonKnightjenl-mp_base.dm_60
# 203123-NeonKnightjenl-mp_base.dm_60
# 203857-NeonKnightjenl-mp_base.dm_60
# 205312-NeonKnightjenl-mp_assault.dm_60
# 205650-NeonKnightjenl-mp_assault.dm_60
# 210031-NeonKnightjenl-mp_assault.dm_60
# 220928-finIJuhan-mp_assault(3putkeen).dm_60
# 223458-finIJuhan-mp_base-(4pf.lla).dm_60
# 02-17-2002-CAL_7_Empire_Handof_HandofDooM_MP_BASE.dm_57
# 200914-WTV-rtcwno-mp_beach.dm_60
# 202121-WTV-rtcwno-mp_beach.dm_60
# 203425-WTV-rtcwno-mp_base.dm_60
# 204646-WTV-rtcwno-mp_base.dm_60
# 210231-WTV-rtcwno-mp_base.dm_60
# BOB_Empire_vs_Krieg_02_28_2002.dm_57
# -=Ec=-Chicago.dm_57
# 210922-z'WyattEarp-mp_ice.dm_60
# 212414-z'WyattEarp-mp_ice.dm_60
# 213350-z'WyattEarp-mp_ice.dm_60
# 215226-z'WyattEarp-mp_ice.dm_60
# 220041-z'WyattEarp-mp_ice.dm_60
# 221238-z'WyattEarp-mp_ice.dm_60
# GA-wCr-vs-o2-mp_base-(WTV-Speakeasy).dm_60
# WTV-ice-beach[K]vs[GMPO]2-1.dm_60
# GA-dot-vs-nurses-mp_ice-wb_finals.dm_60
# 2003-08-15_222022-cKshaftian-mp_beach.dm_60
# 2003-08-15_223328-cKshaftian-mp_beach.dm_60
# 2003-08-15_231005-cKshaftian-mp_beach.dm_60
# CorporalChaos.dm_57
# pM-MD-beach_cb-ivve_3manstrike_breach_beginning.dm_57
# NED_EST_assault_sub_WTV_4039797-WHOLEMATCH.dm_60
# 220353-lc-papa-mp_ice.dm_60
# 221304-WTV-SpeakeasyNET-mp_ice.dm_60
# 223119-WTV-SpeakeasyNET-mp_ice.dm_60
# ocrvaffliction.dm_59
# 211529-[EC]boogie-mp_village.dm_60
# 214122-[EC]boogie-mp_village.dm_60
# 214915-vsedtv-mp_ice.dm_60
# 220226-SnapS'Ripley-mp_ice.dm_60
# 191157-[EYE]Vas-mp_beach.dm_60
# 192648-[EYE]Dolt-mp_beach.dm_60
# 194508-WTV-TnX-mp_beach.dm_60
# 195605-WTV-TnX-mp_beach.dm_60
# 1051843343WarRi0RPovVSLot.dm_60
# 220353-iN-civ-mp_beach.dm_60
# 221313-iN-SoD!-mp_beach.dm_60
# 222320--!cF-Xp!Re-mp_beach.dm_60
# 222712--!cF-Xp!Re-mp_beach.dm_60
# inva.dm_59
# dsvwsw.dm_59
# 1.dm_60
# 2.dm_60
# 3.dm_60
# dot_v_HOG_-_qcon_-_KOSMiX.dm_60
# FIN_NOR_base1_chase_1440659.dm_60
# FIN_NOR_base2_chase_1440659.dm_60
# FIN_NOR_assault_chase_1440659.dm_60
# 200106-cKlethal-mp_village.dm_60
# 200530-cKlethal-mp_village.dm_60
# 200939-cKlethal-mp_village.dm_60
# 203357-cKlethal-mp_village.dm_60
# 204154-cKlethal-mp_village.dm_60
# 211800-cKlethal-mp_village.dm_60
# filled 50 matches in the database
# pM-Snaps-beach_cb-1_25_nice2mandocsecurezam.dm_57
# pM-Snaps-assault_cb-7_00_nicekill_defence.dm_57
# pM-snajpa-village_cb2.dm_57
# unique_vs_wa.dm_60
# unique_vs_wa_1.dm_60
# unique_vs_wa2.dm_60
# ckvs502quakeconassault.dm_59
# o8-euph_mp_assault_1.dm_59
# o8-euph_mp_assault_2.dm_59
# o8-euph_mp_assault_3.dm_59
# o8-euph_mp_assault_4.dm_59
# mp_assault-011956-ocrrep.dm_59
# mp_assault-014038-ocrrep.dm_59
# mp_assault-014645-ocrrep.dm_59
# 222442-WTV-rtcwno-mp_village.dm_60
# 223403-WTV-rtcwno-mp_village.dm_60
# 224041-WTV-rtcwno-mp_beach.dm_60
# 225439-WTV-rtcwno-mp_beach.dm_60
# demo0001.dm_59
# nl_vs_sweden1-mp_village.dm_60
# nl_vs_sweden2-mp_village.dm_60
# nl_vs_sweden3-mp_village.dm_60
# nl_vs_sweden-MP_BEACH.dm_60
# demo0001-5_20_firstattack_aterimgownage.dm_59
# o8_rAd_assault.dm_59
# o8_rAd_base.dm_59
# 212828-WTV-@rtcw-ligade-mp_village.dm_60
# 213419-WTV-@rtcw-ligade-mp_village.dm_60
# 214958-]GaB-jackh4mmer[-mp_village.dm_60
# 221325--DeaDmaNCSC--mp_village.dm_60
# 223946-]GaB-storm[-mp_village.dm_60
# 225410--hom3rCSC--mp_village.dm_60
# 225946--DeaDmaNCSC--mp_village.dm_60
# EST_NOR_ice_wtv_3998439-quarterfinals.dm_60
# demo_01.dm_59
# demo_02.dm_59
# demo_03.dm_59
# demo_04.dm_59
# demo_05.dm_59
# demo_06.dm_59
# demo_07.dm_59
# demo_08.dm_59
# 210851-d1glaws_69-mp_village.dm_60
# 211754-d1glaws_69-mp_village.dm_60
# 212526-d1glaws_69-mp_village.dm_60
# 213256-d1glaws_69-mp_village.dm_60
# 214639-d1glaws_69-mp_village.dm_60
# 195022-GMPOZAF'AMD-mp_base.dm_60
# 195945-4K7Ogdoad-mp_base.dm_60
# 202327-4K7Zommy-mp_base.dm_60
# 202756-WTV-SpeakeasyNET-mp_base.dm_60
# 203243-WTV-SpeakeasyNET-mp_base.dm_60
# 203736-WTV-SpeakeasyNET-mp_base.dm_60
# 021419-aLp3nb0g[HFD]-mp_ice.dm_60
# 022236-pK-synergy-mp_ice.dm_60
# 023107-pK-synergy-mp_ice.dm_60
# 024443-pK-synergy-mp_ice.dm_60
# 213328-vsePink-mp_base.dm_60
# 214502-[xi]monTana-mp_base.dm_60
# 221706-vsevega-mp_beach.dm_60
# 222857-vsePink-mp_beach.dm_60
# 223729-vsedaf3ar-mp_beach.dm_60
# 1024643377ss-dasmick_glo.dm_59
# SM2SemiSnapS-Infront.dm_60
# 211435-[apic'mehukatti]-mp_ice.dm_60
# 212515-WTV-speakeasynet-mp_ice.dm_60
# 214231-[]Darkie-mp_village.dm_60
# 003000-agburvear-mp_ice.dm_60
# 003703-agbjizz-mp_ice.dm_60
# 005104-agburvear-mp_ice.dm_60
# 005803--=NDE=-SomEonE-mp_ice.dm_60
# EuroCupXFinal-Kih-vs-eH!-mp_beach[1].dm_60
# EuroCupXFinal-KiH-vs-eH!-mp_assault[2].dm_60
# demo0001.dm_59
# 124103-ocrkuED-Link-mp_village.dm_60
# 125422-ocrwundaD-Link-mp_village.dm_60
# 131414-ocrmeatD-Link-mp_assault.dm_60
# 132546-ocrcaesD-Link-mp_assault.dm_60
# 133419-WTV-ClanBase-mp_assault.dm_60
# 220530-iN-zam-mp_beach.dm_60
# 221459-iN-zam-mp_beach.dm_60
# 222814-iN-zam-mp_village.dm_60
# 224519-iN-zam-mp_village.dm_60
# 230837-iN-zam-mp_ice.dm_60
# silent_inplanta_barrys.dm_59
# 223403-gmpoVeracious-mp_base.dm_60
# 225229-gmpoVeracious-mp_base.dm_60
# 225637-gmpoVeracious-mp_base.dm_60
# 225944-gmpoVeracious-mp_base.dm_60
# 230412-gmpoVeracious-mp_ice.dm_60
# 231636-gmpoVeracious-mp_ice.dm_60
# Qcon2k3_cK_vs_ocr.dm_60
# noll8_vs_dkh.dm_59
# 1.dm_60
# 2.dm_60
# 3.dm_60
# 4.dm_60
# 073021-iN-civ-mp_village.dm_60
# 075547-wSwelusion-mp_village.dm_60
# iN_vs_spOOks_SM-ligan_WTV.dm_60
# rew_gs_sub1_chase_1341031.dm_59
# rew_gs_sub3_chase_1341031.dm_59
# rew_gs_sub4_chase_1341031.dm_59
# rew_gs_assault1_chase_1341031.dm_59
# rew_gs_assault2_chase_1341031.dm_59
# rew_gs_assault3_chase_1341031.dm_59
# rew_gs_assault4_chase_1341031.dm_59
# 211232-boogieeSports-mp_assault.dm_60
# 212943-[]Intact-mp_assault.dm_60
# 213457-boogieeSports-mp_assault.dm_60
# 214339-Lorteungenofmi-mp_ice.dm_60
# 171244-jifster-mp_beach.dm_60
# 172856-KuNiva-mp_beach.dm_60
# 175731-jifster-mp_beach.dm_60
# 181223-WTV-SpeakeasyNET-mp_beach.dm_60
# 214723-[P]NoOne-mp_beach.dm_60
# 220104-[P]NoOne-mp_beach.dm_60
# 221249-[CB]NoOne-mp_assault.dm_60
# 222428-fizzel-mp_assault.dm_60
# demo0001.dm_59
# 2002-0920-Euph_vs_DR-Vil.dm_59
# 2002-0920-Euph_vs_DR-Ass.dm_59
# godVSpointA1.dm_60
# godVSpointA2.dm_60
# godVSpointA3.dm_60
# godVSpointA4.dm_60
# 05-08-03-dt_vs_ds-Base-Bob2_Part_1-WTV.dm_60
# 05-08-03-dt_vs_ds-Base-Bob2_Part_2-WTV.dm_60
# WTV_CB_OC_Spring2003_GaB_vs_4DM-mp_village-1a.dm_60
# WTV_CB_OC_Spring2003_GaB_vs_4DM-mp_village-1b.dm_60
# WTV_CB_OC_Spring2003_GaB_vs_4DM-mp_village-2-mp_assault-3-4a.dm_60
# WTV_CB_OC_Spring2003_GaB_vs_4DM-mp_assault-4b.dm_60
# 214631-wSwemaciat0r-mp_ice.dm_60
# 220403-wSw$laG-mp_ice.dm_60
# 223024-wSwemaciat0r-mp_ice.dm_60
# 224611-wSwelusion-mp_ice.dm_60
# 231211-wSweVilkillEr-mp_ice.dm_60
# pM-Grym-assault_cb-attack_7_00_4man_endofthatround_manymanyman.dm_57
# pM-Grym-Beach_cb.dm_57
# eslps_sca_planb.dm_59
# 211251-WTV-team-itacom-mp_village.dm_60
# 212107-WTV-team-itacom-mp_village.dm_60
# 212958-WTV-team-itacom-mp_village.dm_60
# 213952-WTV-team-itacom-mp_beach.dm_60
# 214330-WTV-team-itacom-mp_village.dm_60
# 214704-WTV-team-itacom-mp_beach.dm_60
# base_hombre.dm_59
# mp_base-211348-iN-slatte.dm_59
# demo0027.dm_59
# 201740-treff-mp_village.dm_60
# 204336-uk-MerlinatoR-mp_village.dm_60
# 211651-uk-papa-mp_ice.dm_60
# 212600-g1zzY-mp_ice.dm_60
# GA-dot-vs-nurses-mp_frostbite(wtv).dm_60
# 1024714719RooKv54.dm_59
# filled 100 matches in the database
# 1012548435LoCvsTK-5_LoC-Akshun.dm_57
# loc-ari.dm_57
# QC2K2-boh-vs-ocr-sub.dm_59
# 211553-[CB]NoOne-mp_village.dm_60
# 212940-[CB]NoOne-mp_village.dm_60
# 215101-MVD-mp_village.dm_60
# 221205-MVD-mp_beach.dm_60
# 222013-MVD-mp_beach.dm_60
# demo1437.dm_59
# demo1438.dm_59
# demo1439.dm_59
# demo1440.dm_59
# 1086335_Md_Broken_chase_round1_village.dm_59
# 1086335_Md_Broken_chase_round2_village.dm_59
# 1086335_Md_Broken_chase_round3_village.dm_59
# demo1444.dm_59
# demo1445.dm_59
# 1050160227biohazard_dtvslions8_mpsub.dm_60
# 221521-denVidiaRaZiel-mp_base.dm_60
# 222038-denVidiaEesteri-mp_base.dm_60
# 222706-denVidiaNight-mp_base.dm_60
# 223319-WTV-TnX-mp_base.dm_60
# 224353-[]Goatsex-mp_base.dm_60
# pM-gs-beachCP_cb-5_00_pmdefence_vassili4mandocsecure.dm_57
# pM-gs-assaultCP_cb-zam4manbeginning_ceesamnice3manstrikes-gsattack.dm_57
# mp_sub-2002-08-16-191904-mTwaTnwirsi.dm_59
# mp_sub-2002-08-16-192636-mTwaTnwirsi.dm_59
# mp_sub-2002-08-16-193310-mTwaTnwirsi.dm_59
# md1.dm_57
# md2.dm_57
# md3.dm_57
# md4.dm_57
# vs_md_bully5man.dm_57
# vs_md_forwardbunker2.dm_57
# md7.dm_57
# md8.dm_57
# md9.dm_57
# SM2SemiEYE-YD.dm_60
# 1012365427[RBA]beach1.dm_57
# SM-ligan_mot_TW.dm_60
# III-phx-offense(cached.netpov)mp_beach.dm_58
# 215840-IMMorTAL]NARF[-mp_beach.dm_60
# 221835-wSwlaws_69-mp_beach.dm_60
# 223632-Da_G]NARF[-mp_beach.dm_60
# 230541-WarKrime]NARF[-mp_beach.dm_60
# [DS-P]Pat.dm_57
# wtvqconqSNAPSvsLC.dm_60
# 231906-GMPOBLAZE-mp_beach.dm_60
# 232849-[]DeadMeat-mp_beach.dm_60
# 234758-GMPOZEMME-mp_beach.dm_60
# 001609-[]Darkie-mp_beach.dm_60
# 003522-[]DeadMeat-mp_beach.dm_60
# mp_village-201406-[BK]Kobolus.dm_59
# mp_village-202906-[BK]Kobolus.dm_59
# mp_village-203332-[BK]Kobolus.dm_59
# mp_village-204243-[BK]Kobolus.dm_59
# 220409-WTV-rtcwno-mp_beach.dm_60
# 222254-WTV-rtcwno-mp_beach.dm_60
# 222933-WTV-rtcwno-mp_village.dm_60
# 1025216797frvsunique_crokmiten.dm_59
# afvsroc.dm_59
# GS_vs_reW_eSports_Cup_Beach.dm_60
# GS_vs_reW_eSports_Cup_Sub.dm_60
# 221211-Stinger-mp_base.dm_60
# 224429-Stinger-mp_base.dm_60
# 225733-Stinger-mp_sub.dm_60
# 231517-Stinger-mp_sub.dm_60
# mp_ice-210532-la]Gambold.dm_59
# mp_ice-211608-LA]bear.dm_59
# mp_village-213655-LA]bear.dm_59
# mp_village-214520-LA]bear.dm_59
# mp_village-212955-LA]Manolito.dm_59
# mp_village-214359-LA]Manolito.dm_59
# mp_village-212957-LA]bear.dm_59
# mp_village-213536-LA]Fro$tbite.dm_59
# mp_village-214401-LA]Fro$tbite.dm_59
# S62DarkStar.dm_57
# demo0001.dm_59
# 222836-iobcave'CoHo-de_frostbite.dm_60
# 224347-eHSumm3L-de_frostbite.dm_60
# 230305-eHRadical-mp_assault.dm_60
# 231623-eHSoD!-mp_assault.dm_60
# 211121-EiM0r[HFD]-mp_sub.dm_60
# 211635-Commander[HFD]-mp_sub.dm_60
# 213811-Commander[HFD]-mp_sub.dm_60
# in-affliction_beach.dm_59
# 001903-SnapS'HypnoToad-mp_ice.dm_60
# 003910-Af[brian]on-mp_ice.dm_60
# 005603--AcJoHann--mp_ice.dm_60
# sub1.dm_59
# sub2.dm_59
# base1.dm_59
# base2.dm_59
# 223026-gmpoVeracious-mp_base.dm_60
# 224129-gmpoVeracious-mp_base.dm_60
# 224903-gmpoVeracious-mp_base.dm_60
# 225158-gmpoVeracious-mp_base.dm_60
# 225503-gmpoVeracious-mp_base.dm_60
# 232113-gmpoVeracious-mp_base.dm_60
# ASS_ABA_SM_Base.dm_59
# ASS_ABA_SM_Sub.dm_59
# 223857-slap-mongo-mp_assault.dm_60
# 225223-slap-mongo-mp_assault.dm_60
# 230203-slap-mongo-mp_assault.dm_60
# 231057-slap-mongo-mp_assault.dm_60
# 233925-slap-mongo-mp_beach.dm_60
# 1012542044demo0000.dm_57
# 1012542198demo0001.dm_57
# 1012442147Demo_1b-vib-mitch.dm_57
# demo0021.dm_59
# demo0022.dm_59
# demo0023.dm_59
# demo0024.dm_59
# demo0025.dm_59
# demo0026.dm_59
# 083536-WTV-SpeakeasyNET-mp_village.dm_60
# 013101--!cF-K!llaS!n-mp_ice.dm_60
# 015838--!cF-K!llaS!n-mp_ice.dm_60
# 021236--!cF-K!llaS!n-mp_ice.dm_60
# 022759--!cF-K!llaS!n-mp_ice.dm_60
# 024440-madbone-mp_ice.dm_60
# 025141-jel-mp_ice.dm_60
# mp_sub-201054-{3kr}Saxxo.dm_59
# mp_sub-201856-{3kr}Saxxo.dm_59
# mp_sub-202151-{3kr}Saxxo.dm_59
# mp_sub-203517-{3kr}Saxxo.dm_59
# mp_base-203930-{3kr}Saxxo.dm_59
# mp_base-204313-{3kr}Saxxo.dm_59
# mp_base-204612-{3kr}Saxxo.dm_59
# mp_base-210248-{3kr}Saxxo.dm_59
# pM-EIN-assault_cb_cup.dm_57
# pM-EIN-beach_cb_cup.dm_57
# 212448-dolt[mysod]-mp_village.dm_60
# 213523-darv[mysod]-mp_village.dm_60
# 220322-darv[mysod]-mp_assault.dm_60
# 221034-[]Ankel-mp_assault.dm_60
# 221709-[]RaZiel-mp_assault.dm_60
# mp_base-201257-[187]SaVVa.dm_59
# mp_base-201843-[187]SaVVa.dm_59
# mp_base-202813-[187]SaVVa.dm_59
# mp_assault-203459-[187]SaVVa.dm_59
# mp_assault-204014-[187]SaVVa.dm_59
# mp_assault-204532-[187]SaVVa.dm_59
# mp_assault-205123-[187]SaVVa.dm_59
# FF_vs_KiH(Arne).dm_60
# iN_vs_BoH_Assault.dm_59
# 1024619820agbvshxred5.dm_59
# 225733-noob'Chill-mp_ice.dm_60
# 231638-noob'Mickey-mp_ice.dm_60
# 233442-{3kr}Teaz-mp_ice.dm_60
# 201816-sp1ke]NARF[-mp_village.dm_60
# 204416-sp1ke]NARF[-mp_village.dm_60
# 205326-sp1ke]NARF[-mp_village.dm_60
# 213325-unique-waxi-mp_beach.dm_60
# 214942-UNIQUE-RAMZI-mp_beach.dm_60
# 220412-rTg-kraft-mp_village.dm_60
# 223150-rTg-kraft-mp_village.dm_60
# NC_SWE_vs_UK.dm_60
# filled 150 matches in the database
# mp_ice-012041-SkDDiDaC.dm_59
# 1012449284Demo_01.dm_57
# 1012449351Demo_02.dm_57
# 1012449450Demo_03.dm_57
# SWE_EST_ice1_chase_1449836.dm_60
# SWE_EST_ice2_chase_1449836.dm_60
# SWE_EST_sub1_chase_1449836.dm_60
# SWE_EST_sub2_chase_1449836.dm_60
# 201159-w'shDevillino-mp_village.dm_60
# 202232-scelestorichie-mp_village.dm_60
# 204437-scelestoogdoad-mp_base.dm_60
# 204654-WTV-#OwnitschcupII-mp_base.dm_60
# 1.dm_59
# 2.dm_59
# 3.dm_59
# 4.dm_59
# 5.dm_59
# 6.dm_59
# 7.dm_59
# 8.dm_59
# 10.dm_59
# demo-qcon2k3finals.dm_60
# 2003-08-16_010626--a-hollywood-mp_village.dm_60
# 2003-08-16_014932--a-hollywood-mp_village.dm_60
# 2003-08-16_015348--a-hollywood-mp_village.dm_60
# 2003-08-16_015821--a-hollywood-mp_village.dm_60
# 203721-WTV-rtcwno-mp_ice.dm_60
# 205152-ardmyst'c-mp_beach.dm_60
# dT_vs_DS_CAL_playoff.dm_60
# GMPO_vs._A-L_-_Beach_-_ESO_CUP.dm_60
# pM-C-das_boot.dm_57
# pM-C-assault.dm_57
# [cp]dIsRuPtIvE.dm_57
# demo0001.dm_59
# neu2.dm_59
# neu3.dm_59
# 6svsIR_round1a.dm_60
# 6svsIR_round1b.dm_60
# 6svsIR_round2a.dm_60
# 6svsIR_round2b.dm_60
# 6svsIR_round3a.dm_60
# 6svsIR_round3b4a.dm_60
# 6svsIR_round4b.dm_60
# 205814-WTV-@rtcw-ligade-mp_beach.dm_60
# 211928--Venc0rv33--mp_beach.dm_60
# 212543-WTV-@rtcw-ligade-mp_beach.dm_60
# 222130-[inf]p!nden!7-mp_beach.dm_60
# 223717-[inf]p!nden!7-mp_beach.dm_60
# 225116-[inf]APE!-mp_beach.dm_60
# 210752-[CB]Ins0mnia-mp_base.dm_60
# 211222-reAperplan-B-mp_base.dm_60
# 211634-reAperplan-B-mp_base.dm_60
# 213208-[CB]Ins0mnia-mp_base.dm_60
# 215000-embassyplan-B-mp_ice.dm_60
# 220117-[CB]Ins0mnia-mp_ice.dm_60
# tbirdkiri.dm_57
# ASS_vs_TW_SM-ligan.dm_60
# WTV_rtcwl-sw_Ocr-CSC_beach_1.dm_60
# WTV_rtcwl-sw_Ocr-CSC_beach_2.dm_60
# WTV_rtcwl-sw_Ocr-CSC_beach_3.dm_60
# WTV_rtcwl-sw_Ocr-CSC_beach_4.dm_60
# WTV_rtcwl-sw_Ocr-CSC_beach_5.dm_60
# 201335-godmor1tz-mp_keep.dm_60
# ckvsimagine.dm_59
# 211829-[187]boogie-mp_village.dm_60
# 214734-[187]boogie-mp_village.dm_60
# 221224-[187]boogie-mp_village.dm_60
# 022906-ocrkuED-Link-mp_beach.dm_60
# 024708-ocrvAdD-Link-mp_beach.dm_60
# 030427-ocrdeepD-Link-mp_beach.dm_60
# 032248-ocrcaesD-Link-mp_beach.dm_60
# 033520-ocrkuED-Link-mp_beach.dm_60
# 212613-sE-civ-mp_assault.dm_60
# 214130-sE-civ-mp_assault.dm_60
# 220810-sE-civ-mp_ice.dm_60
# 1012370013BoB_seppuku_v_GAT_rd01.dm_57
# 1012370163BoB_seppuku_v_GAT_rd03.dm_57
# 1012370316BoB_seppuku_v_GAT_rd04.dm_57
# iN_vs_Sp00ks.dm_59
# demo0166.dm_60
# Alpha-Beta_1.dm_59
# Alpha-Beta_2.dm_59
# Alpha-Beta_3.dm_59
# Alpha-Beta_4.dm_59
# 11-07-02-dt_vs_ds-Beach-CALPLAYOFFS.dm_59
# 221318-[papa]-mp_assault.dm_60
# 222903-[papa]-mp_assault.dm_60
# 224501-[papa]-mp_base.dm_60
# 224808-[kiz]-mp_base.dm_60
# 1055825019[pb]rufugio-mp_ice-panzer_bitches-v-trinity.dm_60
# FAFirefly.dm_57
# part1_in-ck_assault.dm_59
# part2_in-ck_assault.dm_59
# demo0001.dm_59
# 1025054753hank.dm_59
# ECX_dignitas_vs_emaho_SEMIFINALS_mp_beach3.dm_60
# ECX_dignitas_vs_emaho_SEMIFINALS_mp_beach4.dm_60
# ECX_dignitas_vs_emaho_SEMIFINALS_base1.dm_60
# ECX_dignitas_vs_emaho_SEMIFINALS_base2.dm_60
# ECX_dignitas_vs_emaho_SEMIFINALS_base3.dm_60
# ECX_dignitas_vs_emaho_SEMIFINALS_base4.dm_60
# 201906-WFL'RefereESanTa-mp_base.dm_60
# 204622-WFL'RefereESanTa-mp_base.dm_60
# Toe_Tag.dm_57
# mp_beach-2002-08-17-091054-Justice-P-.dm_59
# mp_beach-2002-08-17-092531-ShadoWeN-P-.dm_59
# 021608-vinz-mp_beach.dm_60
# 022819-crit-mp_beach.dm_60
# 023535-madbone-mp_beach.dm_60
# 025810-crit-mp_beach.dm_60
# 222037-raMeSports-mp_beach.dm_60
# 224806-raMeSports-mp_assault.dm_60
# 232107-rameSports-mp_base.dm_60
# 4K_v_OMG_BoB_Final_p1.dm_60
# 4K_v_OMG_BoB_Final_p2.dm_60
# dt_vs_narf_cal-m.finals.mp_beach.dm_60
# 221702-absolutHoMBre!]-mp_assault.dm_60
# 222749-]+[ZaF-mp_assault.dm_60
# 223511-]+[ZaF-mp_beach.dm_60
# 224929-WTV-speakeasynet-mp_beach.dm_60
# demo0001.dm_59
# demo0002.dm_59
# 211440-wScver!tas-mp_beach.dm_60
# 214540-CoH]I[ToniwSc-mp_village.dm_60
# 215446-WTV-@rtcw-ligade-mp_village.dm_60
# 220933-CoH]I[Smoove-mp_village.dm_60
# 221716-CoH]I[Inuit-mp_village.dm_60
# com_vs_tv_base2_sta_finals_1.dm_60
# com_vs_tv_base2_sta_finals_2.dm_60
# -a-brian-vs-ds-cal-i-playoffs-village.dm_59
# filled 200 matches in the database
# podvshk1.dm_59
# 211202___R0NIN_MP_VILLAGE.DM_60
# 223221_WAX_ESPORT_MP_BASE.DM_60
# 224423__TITAN_MP_BASE.DM_60
# 224700__DOLT_MP_BASE.DM_60
# 225512_O8INFAN_MP_BASE.DM_60
# 230602_O8ALBAN_MP_VILLAGE.DM_60
# 232748__RUTJE_MP_VILLAGE.DM_60
# 233447_WAX_ESPORT_MP_VILL.DM_60
# SM-Ligan_Merge_-_Sill_POV_s3VVi.dm_60
# pM-Snajpa-assault_cb.dm_57
# 172949-4K7Yilider-mp_village.dm_60
# 174515-4K7Creamy-mp_village.dm_60
# 180351-4K7Creamy-mp_village.dm_60
# bob-empire-vs-hv-sub-22102.dm_57
# alternative_wtv_in_vs_a.dm_60
# mvshf_71_1.dm_59
# 043211-iN-SoD!-mp_assault.dm_60
# 043945-iN-SoD!-mp_assault.dm_60
# 044749-iN-SoD!-mp_assault.dm_60
# 051537-iN-SoD!-mp_assault.dm_60
# pM-3kr-assault_1.dm_57
# pM-3kr-assault_2.dm_57
# pM-3kr-village-veryclosevillagtransmit.dm_57
# 210213-[]DeadMeat-mp_assault.dm_60
# 211507-WTV-TnX-mp_assault.dm_60
# 214137-[]RaZiel-mp_assault.dm_60
# 214949-iN-Summ3Lypg-mp_assault.dm_60
# 205949-WTV-@rtcw-ligade-mp_village.dm_60
# 215503-u$FRuSsAk-mp_assault.dm_60
# 220246-vCcaXe!-mp_assault.dm_60
# 221639-vCccYx!-mp_assault.dm_60
# 234418-PhoenixTSA-mp_beach.dm_60
# 235840-PhoenixTSA-mp_beach.dm_60
# 212318--DeaDmaNCSC--mp_ice.dm_60
# 213911-sPx-aYb--mp_ice.dm_60
# demo0151.dm_60
# DkHvsBS_base.dm_59
# 214218-finIveracious-mp_base.dm_60
# 221310-finIveracious-mp_base.dm_60
# 222702-finIveracious-mp_village.dm_60
# 223407-finIveracious-mp_village.dm_60
# 224440-finIveracious-mp_village.dm_60
# BlueThunder.dm_57
# XI_v_OMG_BoB_170203_LB_FINALS.dm_60
# 212247-sE-SoD!-mp_beach.dm_60
# 213335-sE-Summ3L-mp_beach.dm_60
# 214026-sE-Summ3L-mp_beach.dm_60
# 214534-uk-decay-mp_beach.dm_60
# 215347-sE-wuff-mp_village.dm_60
# 215751-uk-decay-mp_village.dm_60
# 220057-sE-wuff-mp_village.dm_60
# 221148-sE-spear-mp_village.dm_60
# demo01.dm_59
# mp_assault-212713-[P]NoOne.dm_59
# mp_assault-215302-[P]NoOne.dm_59
# mp_sub-220243-[P]NoOne.dm_59
# mp_sub-220634-[es7'MenaCe].dm_59
# mp_sub-221041-[P]NoOne.dm_59
# 221530-FF-0kla-icemat!-mp_beach.dm_60
# 222242-FF-0kla-icemat!-mp_beach.dm_60
# 223727-FF-0kla-icemat!-mp_ice.dm_60
# 225845-FF-0kla-icemat!-mp_ice.dm_60
# rew-cows_ice1.dm_60
# rew-cows_ice2.dm_60
# rew-cows_ice3.dm_60
# rew-cows_ice4.dm_60
# rew-cows_beach5.dm_60
# rew-cows_beach6.dm_60
# rew-cows_beach7.dm_60
# rew-cows_beach8.dm_60
# ned_swe_assaut_wtv_1_.dm_60
# ned_swe_assaut_wtv_2_.dm_60
# ned_swe_frostbite_wtv.dm_60
# rtcw_2003.06.30_ga-ladder-s3_dot_vs_nurses_finals.dm_60
# 204606-rTgThe-Light-mp_village.dm_60
# 210227-rTgThe-Light-mp_village.dm_60
# 211051-rTgThe-Light-mp_village.dm_60
# 212046-rTgThe-Light-mp_village.dm_60
# 212653-rTgThe-Light-mp_village.dm_60
# 214026-rTgThe-Light-mp_ice.dm_60
# 214640-rTgThe-Light-mp_ice.dm_60
# 215051-rTgThe-Light-mp_ice.dm_60
# 220138-rTgThe-Light-mp_ice.dm_60
# RTCW.NO-id.no_vs_Ocrana-mp_ice-Round1.dm_60
# RTCW.NO-id.no_vs_Ocrana-mp_ice-Round2.dm_60
# RTCW.NO-id.no_vs_Ocrana-mp_village-Round1.dm_60
# RTCW.NO-id.no_vs_Ocrana-mp_village-Round2.dm_60
# demo01.dm_60
# S62Gungadi.dm_57
# demo0023-ape.dm_60
# 02-10-2002-phx_empire_calweek6.dm_57
# 210607-WTV-ClanBase-mp_assault.dm_60
# 212740-red[mysod]-mp_assault.dm_60
# 213310-WTV-ClanBase-mp_assault.dm_60
# 214011-WTV-ClanBase-mp_beach.dm_60
# 214833-IKILun4t1C-mp_beach.dm_60
# ICF_vs_DOS_Part_1.dm_60
# ICF_vs_DOS_Part_2.dm_60
# ICF_vs_DOS_Part_3.dm_60
# ICF_vs_DOS_Part_4.dm_60
# ICF_vs_DOS_Part_5.dm_60
# 211746-Summ3Lse-te_frostbite.dm_60
# 212531-Summ3Lse-te_frostbite.dm_60
# 214220-WTV-ClanBase-mp_village.dm_60
# 215153-kritoso-mp_village.dm_60
# 220205-viX_o-mp_village.dm_60
# 220846-pikkense-mp_village.dm_60
# 01_mp_base-OCRANAvsDiY_QCon1.dm_59
# 02_mp_base-OCRANAcsDiY_Qcon2.dm_59
# 1024450222DIY_TF.dm_59
# 1012371601demo01drmack.dm_57
# de-ocr_ice1.dm_60
# de-ocr_ice2.dm_60
# de-ocr_ice3.dm_60
# de-ocr_ice4.dm_60
# de-ocr_beach5.dm_60
# de-ocr_beach6.dm_60
# de-ocr_beach7.dm_60
# de-ocr_beach8.dm_60
# demo0001.dm_60
# demo0002.dm_60
# demo0003.dm_60
# demo0004.dm_60
# demo0005.dm_60
# demo0006.dm_60
# 4KvsIM.dm_60
# pM-Gs-beach_CB-twicebeginningzamkilledbybomb_clutchdocsecure_kindarandomtho.dm_57
# pM-Gs-assault_CB-pmdefenecafterwait_morsussmg_vasilisniperafter.dm_57
# Avenger.dm_57
# 211514-[]DeadMeat-mp_beach.dm_60
# 213355--og-binBASH-mp_beach.dm_60
# 215045--og-zioN'-mp_beach.dm_60
# 215937-[]myst'x-mp_beach.dm_60
# 194558-nationscupIfrozen-mp_base.dm_60
# 195422-nationscupIfrozen-mp_base.dm_60
# 200141-nationscupIfrozen-mp_base.dm_60
# 200950-nationscupIfrozen-mp_base.dm_60
# 201537-nationscupIfrozen-mp_assault.dm_60
# 203304-nationscupIfrozen-mp_assault.dm_60
# 203904-nationscupIfrozen-mp_assault.dm_60
# 101155-tofu-mp_assault.dm_60
# ard-in_beach1.dm_60
# ard-in_beach2.dm_60
# ard-in_beach3.dm_60
# ard-in_ice4.dm_60
# ard-in_ice5.dm_60
# ard-in_ice6.dm_60
# ard-in_ice7.dm_60
# Lem_v_@_eSports_Cup_Beach.dm_60
# Lem_v_@_eSports_Cup_Sub.dm_60
# 202050-Nadja-mp_assault.dm_60
# 204357-MVD-mp_assault.dm_60
# 204931-MVD-mp_assault.dm_60
# 210251-MVD-mp_assault.dm_60
# 211705-MVD-mp_village.dm_60
# 212313-MVD-mp_village.dm_60
# 212919-MVD-mp_village.dm_60
# 214053-MVD-mp_village.dm_60
# 212634-[]myst'x-mp_village.dm_60
# 213513-[]EvilPurc-mp_village.dm_60
# 215151-[]myst'x-mp_village.dm_60
# 221143-[]Darkie-mp_beach.dm_60
# 223002-WTV-TnX-mp_beach.dm_60
# noll8_vs_dkh.dm_59
# filled 250 matches in the database
# WTV_SNAPSvsEYE.dm_60
# 1025237078YOURE_MOM.dm_59
# 213425-MVD-mp_village.dm_60
# 214550-MVD-mp_village.dm_60
# 215500-MVD-mp_village.dm_60
# 220008-MVD-mp_village.dm_60
# 221919-helixhardy-mp_ice.dm_60
# 222510-helixPBreazer-mp_ice.dm_60
# 223614-helixfLiPMo-mp_ice.dm_60
# 224735-helixhardy-mp_ice.dm_60
# 203343-rTgHabakuKKSTORMIX-mp_ice.dm_60
# 204803-rTghOOlig@n-mp_ice.dm_60
# 210508-[ROR]Carlos-mp_ice.dm_60
# 211456-rTgShooterSTORMIX-mp_ice.dm_60
# 1013146769Demo_01.dm_57
# 1012447262bob-round1-05.dm_57
# 1012445636m1rd6fate.dm_57
# 210644-ihpPsymon-mp_village.dm_60
# 211229-ihpGrandPa-mp_village.dm_60
# 211759-=]WoS[=E!xxx-mp_village.dm_60
# 212239-WTV-@rtcw-ligade-mp_village.dm_60
# 213039-=]WoS[=Bavarica-mp_village.dm_60
# 213950-=]WoS[=E!xxx-mp_village.dm_60
# 214535-=]WoS[=Bavarica-mp_village.dm_60
# 215424-ihpfiTz-mp_village.dm_60
# 220516-ihpXHeli-mp_village.dm_60
# 221319-ihpfiTz-mp_village.dm_60
# 221939-=]WoS[=Bisage-mp_village.dm_60
# 223154-ihpfiTz-mp_village.dm_60
# 1012447259demo0005.dm_57
# 1012448091demo0006.dm_57
# 010045-HaVoC-mp_ice.dm_60
# 010916-iN-Spear-mp_ice.dm_60
# 013812-HaVoC-mp_ice.dm_60
# 192610-iN-Sw33t-mp_assault.dm_60
# 194100-ex!stSupa-mp_assault.dm_60
# 195809-WaZeSports-mp_ice.dm_60
# 200515-iN-civ-mp_ice.dm_60
# 1.dm_60
# 2.dm_60
# 3.dm_60
# swf_vs_SILL_SM_021016.dm_59
# 201634-[]RuStY-mp_beach.dm_60
# 202553-]GaB-unb0[-mp_beach.dm_60
# 203449-]GaB-unb0[-mp_beach.dm_60
# 204705-]GaB-unb0[-mp_beach.dm_60
# 12-04-2001-III_vs_Fh_7(fredo).dm_57
# 211147-SnapS'CapteN-mp_beach.dm_60
# 212459-WTV-EFTERLYST-mp_beach.dm_60
# 213711-WTV-EFTERLYST-mp_beach.dm_60
# 001035-carncrim-mp_assault.dm_60
# 005601-carnMadnesS-mp_assault.dm_60
# podvsocr.dm_59
# 1024461165AMO_v_S_Qcon_Ice_SeedyEx.dm_59
# 202828-rTgSpiKe-mp_village.dm_60
# 204027-rTgSpiKe-mp_village.dm_60
# 205548-rTgSpiKe-mp_village.dm_60
# 210029-rTgSpiKe-mp_village.dm_60
# 210643-rTgSpiKe-mp_base.dm_60
# 211042-rTgSpiKe-mp_base.dm_60
# 212009-rTgSpiKe-mp_base.dm_60
# 212907-rTgSpiKe-mp_base.dm_60
# 194438-argh]![D4rkDeVil-mp_village.dm_60
# 200141-argh]![D4rkDeVil-mp_village.dm_60
# 200924-argh]![D4rkDeVil-mp_village.dm_60
# 202540--mbISajeZ--mp_village.dm_60
# 205030-ws][-v3d--mp_village.dm_60
# 210123-[goq'stone]-mp_village.dm_60
# 211349-ws][Homer-mp_village.dm_60
# 211831-ws][Ic3-mp_village.dm_60
# 212800-[goq'DarkWing]-mp_base.dm_60
# 213158-ws][Homer-mp_base.dm_60
# 213822-ws][-v3d--mp_base.dm_60
# 215213-ws][Tallsaxon-mp_base.dm_60
# 201234-uk-ninjai-mp_beach.dm_60
# 202209-uk-ninjai-mp_beach.dm_60
# 203758-zenonno-mp_village.dm_60
# 204628-uk-Creamy-mp_village.dm_60
# 205340-chouelno-mp_village.dm_60
# 200858-[+]CapteN-mp_village.dm_60
# 202935-[+]hedgeHog-mp_village.dm_60
# 203703-[+]CapteN-mp_village.dm_60
# 204624-[+]scAle-mp_beach.dm_60
# 205857-[+]Spear-mp_beach.dm_60
# 4k_vs_eSports_cbint_17062002_village.dm_59
# 4k_vs_eSports_cbint_17062002_beach.dm_59
# pM-Md-Communique_cb-beginning3mansod_11_50-4manzam_mdattack_14_20_4mansumm3l.dm_57
# pM-Md-Assault_cb.dm_57
# inf-apeVSinverse.dm_60
# 165646-4K7Zommy-mp_beach.dm_60
# 171409-4K7Zommy-mp_beach.dm_60
# 172501-4K7Creamy-mp_beach.dm_60
# 175439-WTV-SpeakeasyNET-mp_beach.dm_60
# demo_1.dm_59
# demo_2.dm_59
# demo0150.dm_60
# slutter.dm_58
# 211703-LA]Fro$tbite-mp_base.dm_60
# 213837-LA]bear-mp_base.dm_60
# 214353-la]Gambold-mp_base.dm_60
# 215238-LA]Manolito-mp_base.dm_60
# demo0154.dm_60
# gmpo-frontline-ice-1.dm_60
# gmpo-frontline-ice-2.dm_60
# gmpo-frontline-ice-3.dm_60
# gmpo-frontline-ice-4.dm_60
# gmpo-frontline-ice-5.dm_60
# gmpo-frontline-ice-6.dm_60
# gmpo-frontline-ice-7.dm_60
# gmpo-frontline-ice-8.dm_60
# gmpo-frontline-ice-9.dm_60
# gmpo-frontline-ice-10.dm_60
# gmpo-frontline-ice-11.dm_60
# gmpo-frontline-ice-12.dm_60
# ocrana_oct_wtv.dm_60
# Gs_vs_187_Assault.dm_60
# GS_vs_187_Ice.dm_60
# GS_vs_187_Beach_Tie_Breaker.dm_60
# mp_sub-221359-[CUP]Veracious.dm_59
# mp_sub-221811-[CUP]Veracious.dm_59
# mp_sub-222842-[CUP]Veracious.dm_59
# mp_assault-223712-[CUP]Veracious.dm_59
# mp_assault-225623-[CUP]Veracious.dm_59
# mp_assault-230317-[CUP]Veracious.dm_59
# eH_vs_FF1.dm_60
# eH_vs_FF2.dm_60
# pM_mirage_village_free_1_884777.dm_57
# pM_mirage_village_free_4_884777.dm_57
# pM_mirage_base_free_1_884777.dm_57
# pM-mirage-base_cbcup-13_20_mygi_5man.dm_58
# 222904-n2y-plan-B-mp_base.dm_60
# 223634-n2y-plan-B-mp_base.dm_60
# 224014-n2y-plan-B-mp_base.dm_60
# 1025061344excon-wsw-vs-sbc-qcon.dm_59
# 1012415192Canadian_Throwing_Wangs_vs_The_Portuguese.dm_57
# 221624-sod-ramzi-mp_ice.dm_60
# 223443-sod-ramzi-mp_assault.dm_60
# 224359-sod-ramzi-mp_assault.dm_60
# 225928-sod-ramzi-mp_assault.dm_60
# 213228-absolutSw33t!8-mp_beach.dm_60
# 215237-[CB]NoOne-mp_beach.dm_60
# 220742-MVD-mp_village.dm_60
# 221515-MVD-mp_village.dm_60
# 222118-MVD-mp_village.dm_60
# EYE_vs_SnapS_EC_WTV.dm_60
# demo0001.dm_59
# demo0002.dm_59
# 1.dm_60
# 2.dm_60
# 3.dm_60
# 4.dm_60
# kodvspimps.dm_60
# 1012368243HV-vup-beach-round1.dm_57
# 1012369757HV-vup-beach-round2.dm_57
# OMG_v_Aurora_BoB_200103_-UP_SEMI_FINALS.dm_60
# wdvssqd.dm_59
# filled 300 matches in the database
# demo0011.dm_59
# 201922-WTV-rtcwno-mp_village.dm_60
# 203223-WTV-rtcwno-mp_village.dm_60
# 203951-WTV-rtcwno-mp_village.dm_60
# 205023-WTV-rtcwno-mp_village.dm_60
# 210453-WTV-rtcwno-mp_beach.dm_60
# 212019-WTV-rtcwno-mp_beach.dm_60
# LEM_v_T34_Assault_-_eSports_Cup.dm_60
# LEM_v_T34_Ice_-_eSports_Cup.dm_60
# WDvsZB_-_eSports_Cup_Base1.dm_60
# WDvsZB_-_eSports_Cup_Base2.dm_60
# WDvsZB_-_eSports_Cup_Beach.dm_60
# A_VS_WSW.dm_59
# gf_vs_ocr_eslplayoff.dm_60
# 194218-nightfallHV-mp_beach.dm_60
# 200224-grimdeathHV-mp_beach.dm_60
# 201019-grimdeathHV-mp_beach.dm_60
# 01_1012620047OGL-FHvB0NE-$pline-2.dm_57
# 02_1012619999OGL-FHvB0NE-$pline-3.dm_57
# 03_1012619552round5-6.dm_57
# 04_1012619346round8.dm_57
# 05_1012619280round9-10.dm_57
# 220438-ocrkuED-Link-mp_assault.dm_60
# 220915-ocrkuED-Link-mp_assault.dm_60
# 221656-ocrkuED-Link-mp_assault.dm_60
# 224240-ocrkuED-Link-mp_assault.dm_60
# 214333-[CB]Ins0mnia-mp_village.dm_60
# 215740-[CB]Ins0mnia-mp_village.dm_60
# 220959-n2y-plan-B-mp_sub.dm_60
# 221922-r0taxplan-B-mp_sub.dm_60
# 1.dm_60
# 2.dm_60
# 3.dm_60
# 4.dm_60
# 210715-T$tarksSI-mp_sub.dm_60
# 211654-T$tarksSI-mp_sub.dm_60
# 214205-T$tarksSI-mp_sub.dm_60
# 220239-T$tarksSI-mp_sub.dm_60
# Finland_vs_Austria_base.dm_60
# Finland_vs_Austria_village.dm_60
# 1024721447-a-BrIaN-vs-mM-Qcon-Qualifiers-Ice(1).dm_59
# redem.finals.dm_60
# 210655-Bully-mp_beach.dm_60
# 212010-Bully-mp_beach.dm_60
# 215452-Bully-mp_village.dm_60
# 222016-Bully-mp_village.dm_60
# 005601-carnMadnesS-mp_assault.dm_60
# 013122-agbvaaaaaaaaaaaaaash-mp_assault.dm_60
# 015212-agbredfive-mp_assault.dm_60
# dogma_hfh_vs_or.dm_59
# 214734-MVD-mp_ice.dm_60
# 221400-MVD-mp_ice.dm_60
# 223744-MVD-mp_ice.dm_60
# 230040-MVD-mp_ice.dm_60
# 231820-MVD-mp_ice.dm_60
# 1012354498demo0004.dm_57
# 1012354551demo0005.dm_57
# 1012355185demo0006.dm_57
# 1012355224demo0007.dm_57
# 215732-eHciv-mp_beach.dm_60
# 221338-eHzam-mp_beach.dm_60
# 222506-eHciv-mp_village.dm_60
# 224506-eHSumm3L-mp_village.dm_60
# 225007-geek{celtiC}-mp_village.dm_60
# demo0006.dm_60
# demo0007.dm_60
# demo0008.dm_60
# demo0009.dm_60
# demo0010.dm_60
# 2002_09_15_bary_DkHvs4kbase.dm_59
# pM-boh-assault_cb.dm_57
# pM-boh-beach_cb-3_40_bohdefence_reptile.dm_57
# demo_8.dm_57
# demo_1.dm_57
# demo_2.dm_57
# demo_3.dm_57
# demo_4.dm_57
# demo_5.dm_57
# demo_6.dm_57
# demo_7.dm_57
# 200958-uk-papa-te_frostbite.dm_60
# 201749-uk-crmbs-te_frostbite.dm_60
# 203557-NL-lus3D-mp_village.dm_60
# 210300-uk-crmbs-mp_village.dm_60
# 235736-GMPOZAF'AMD-mp_base.dm_60
# in-acf_ice1.dm_60
# in-acf_ice2.dm_60
# in-acf_ice3.dm_60
# in-acf_ice4.dm_60
# in-acf_village5.dm_60
# in-acf_village6.dm_60
# in-acf_village7.dm_60
# in-acf_village8.dm_60
# 203306-Sengo'RaGE!-mp_assault.dm_60
# 204222-Sengo'RaGE!-mp_assault.dm_60
# 205000-Sengo'RaGE!-mp_assault.dm_60
# 205500-Sengo'RaGE!-mp_assault.dm_60
# o8_vs_VSE_eSports_Cup_Assault.dm_60
# o8_vs_VSE_eSports_Cup_Ice.dm_60
# 073154-AmishHAAS-mp_ice.dm_60
# 074230-AmishGig'qconcfg-mp_ice.dm_60
# 075922-AmishHAAS-mp_ice.dm_60
# demo0001.dm_59
# 222304-NL-RATEM-mp_base.dm_60
# 223959-NL-RATEM-mp_base.dm_60
# 225542-NL-Jappio-mp_base.dm_60
# 230252-kuE-mp_ice.dm_60
# 231853-saber-mp_ice.dm_60
# 233700-Chris-mp_beach.dm_60
# 234944-kuE-mp_beach.dm_60
# 235559-saber-mp_beach.dm_60
# demo0000.dm_57
# demo0001.dm_57
# demo0002.dm_57
# demo0003.dm_57
# demo0004.dm_57
# demo0005.dm_57
# demo0006.dm_57
# demo0007.dm_57
# doctors-abuse-mp_assault_wolftv.dm_59
# cK-dr_cal_beach(valdez).dm_58
# mp_sub-172351-drwom!.dm_59
# mp_sub-173107-drwom!.dm_59
# mp_sub-173530-drw!$eGUy.dm_59
# mp_sub-174219-mTwaTnVirus.dm_59
# 200600-NuFTORN-mp_beach.dm_60
# 201311-DwDMaxPower-mp_beach.dm_60
# 201656-NuFCHECKOFF-mp_beach.dm_60
# 202201-NuFjAcKy_U-mp_beach.dm_60
# 203116-NuFR!ffRaff-mp_village.dm_60
# 203906-NuFLEmbO-mp_village.dm_60
# 205122-DwDB4vAri4-mp_village.dm_60
# 205937-NuFR!ffRaff-mp_village.dm_60
# minvsrew3.dm_60
# 201649-[ACF]Jappio-mp_beach.dm_60
# 203249-WTV-rtcwno-mp_beach.dm_60
# 204500-[ACF]EisenHower-mp_base.dm_60
# 211033-WTV-rtcwno-mp_base.dm_60
# pM-snaps-castle_CUP.dm_57
# pM-snaps-beach_CUP.dm_57
# 1024550821ds-naz-gat.dm_59
# 211412-bbvse_and_co-dafear-mp_base.dm_60
# 214657-bbvse_and_co-dafear-mp_base.dm_60
# 215036-bbvse_and_co-dafear-mp_base.dm_60
# 215448-bbvse_and_co-dafear-mp_base.dm_60
# 215827-bbvse_and_co-dafear-mp_base.dm_60
# 221207-bbvse_and_co-dafear-mp_base.dm_60
# 223000-bbvse_and_co-dafear-mp_base.dm_60
# 193521-AmishSeed-mp_assault.dm_60
# 194224-AmishSeed-mp_assault.dm_60
# 195708-AmishSeed-mp_assault.dm_60
# 200825-AmishSeed-mp_assault.dm_60
# 201523-AmishSeed-mp_assault.dm_60
# 202651-AmishSeed-mp_assault.dm_60
# 203812-AmishSeed-mp_assault.dm_60
# 205332-AmishSeed-mp_assault.dm_60
# GER_vs_ITA_base_fizzel_runde1.dm_60
# GER_vs_ITA_base_fizzel_runde2.dm_60
# GER_vs_ITA_base_fizzel_runde3.dm_60
# GER_vs_ITA_base_fizzel_runde4.dm_60
# 203028-rTgSpiKe-mp_base.dm_60
# 203521-rTgSpiKe-mp_base.dm_60
# 203956-rTgSpiKe-mp_base.dm_60
# 205726-rTgSpiKe-mp_base.dm_60
# 211824-rTgSpiKe-mp_assault.dm_60
# 212446-rTgSpiKe-mp_assault.dm_60
# 212847-rTgSpiKe-mp_assault.dm_60
# 213953-rTgSpiKe-mp_assault.dm_60
# 1050443374VillageAgainstAC.dm_60
# 213045-helixpulley-mp_village.dm_60
# 221118-ocrloveD-Link-mp_village.dm_60
# 222109-helixPBreazer-mp_village.dm_60
# 223105-ocrkasD-Link-mp_village.dm_60
# 225159-MVD-mp_village.dm_60
# 230221-ocrkasD-Link-mp_village.dm_60
# rew_vs_187.dm_60
# demo0144.dm_60
# filled 350 matches in the database
# snaps.vs.infensus-intour_finals.mp_base_(wolftv).dm_60
# CBNC_Winter2002_GER_vs_FRA_beach1.dm_60
# CBNC_Winter2002_GER_vs_FRA_beach2.dm_60
# CBNC_Winter2002_GER_vs_FRA_village1.dm_60
# CBNC_Winter2002_GER_vs_FRA_village2.dm_60
# 193412-ocrfizzD-Link-mp_base.dm_60
# 193916-d3v[M]-mp_base.dm_60
# 194338-WaZeSports-mp_base.dm_60
# 195403-WaZeSports-mp_base.dm_60
# 195726-ocrkuED-Link-mp_beach.dm_60
# 200857-WaZeSports-mp_beach.dm_60
# 002019-reAperplan-B-mp_ice.dm_60
# 002628-(177)Krypes-mp_ice.dm_60
# 010758-(177)Krypes-mp_ice.dm_60
# 211522-scelestoyilider-mp_assault.dm_60
# 213655-scelestoCreamy-mp_assault.dm_60
# 215407-scelestocrmbs-mp_ice.dm_60
# 220344-scelestoCreamy-mp_ice.dm_60
# 231719-WTV-SpeakeasyNET-mp_ice.dm_60
# 233620-SnapS'Phanta-mp_ice.dm_60
# 235704-SnapS'Phanta-mp_ice.dm_60
# allstar2k3.dm_60
# 12-11-2001-III-vs-HEL-game8-assault-fredo_Hells_Elite_Legions_12-11-01_cal1preseason.dm_57
# lqd_vs_handof_bob2.dm_60
# dLm_vs_COH_mp_keep.dm_60
# bohvmtw.dm_59
# 201751-AmishSeed-mp_beach.dm_60
# 203504-cKshaftian-mp_beach.dm_60
# 205109-AmishJimmyJack-mp_beach.dm_60
# 213211-BugBeaRcave'CoH8)-mp_ice.dm_60
# 213857-rTg-fixi-mp_ice.dm_60
# 215515-iobcave'CoHo-mp_base.dm_60
# 221241-rTg-spik3-mp_base.dm_60
# 221605-rTg-schleck3r-mp_base.dm_60
# 222346-rTg-we4K!-mp_base.dm_60
# mp_sub-2002-08-16-174905-WatFireBlaDe.dm_59
# mp_sub-2002-08-16-175250-Watfluidfive.dm_59
# mp_sub-2002-08-16-175723-WatFireBlaDe.dm_59
# mp_sub-2002-08-16-180947-WatKamiKaZe.dm_59
# mp_sub-2002-08-16-181731-WatNauCe.dm_59
# 223316-[CUP]Veracious-mp_ice.dm_59
# 224541-[CUP]Veracious-mp_ice.dm_59
# 230621-[CUP]Veracious-mp_village.dm_59
# 231939-[CUP]Veracious-mp_village.dm_59
# 233439-[CUP]Veracious-mp_village.dm_59
# sta-finals.dm_60
# 220727-4K7Zommy-mp_village.dm_60
# 221827-4K7Creamy-mp_village.dm_60
# 224530-4K7Explicit-mp_beach.dm_60
# 230228-4K7Ogdoad-mp_beach.dm_60
# 212749-[+]CapteN-mp_base.dm_60
# 215407-[+]CapteN-mp_base.dm_60
# 220202-[+]CapteN-mp_base.dm_60
# 222200-[+]CapteN-mp_assault.dm_60
# 222726-[+]CapteN-mp_assault.dm_60
# 213006-TWStingray-mp_base.dm_60
# 214724-[ABA]Fnorg-mp_base.dm_60
# 215335-TWStingray-mp_base.dm_60
# 215845-TWStingray-mp_base.dm_60
# 220306-[ABA]Burrito-mp_base.dm_60
# 222705-TWLinda-mp_base.dm_60
# SigEpWi.dm_57
# retail_vs_demo_assault.dm_60
# retail_vs_demo_beach.dm_60
# 221515-Kobo@pwde-mp_beach.dm_60
# 223705-MVD-mp_beach.dm_60
# 225146-MVD-mp_base.dm_60
# 230146-MVD-mp_base.dm_60
# 230709-MVD-mp_base.dm_60
# 187vBB_eSports_Cup_-_Base.dm_59
# 187vBB_eSports_Cup_-_Beach.dm_59
# dsvsdrmatch.dm_57
# gZ-de_beach1.dm_60
# gZ-de_beach2.dm_60
# gZ-de_beach3.dm_60
# gZ-de_beach4.dm_60
# gZ-de_village5.dm_60
# gZ-de_village6.dm_60
# gZ-de_village7.dm_60
# gZ-de_village8.dm_60
# 1012528474Flipside79UVWvs86.dm_57
# One_vs_PlanB_eSports_Cup_-_Assault1.dm_60
# One_vs_PlanB_eSports_Cup_-_Assault2.dm_60
# One_vs_PlanB_eSports_Cup_-_Assault3.dm_60
# One_vs_PlanB_eSports_Cup_-_Assault4.dm_60
# One_vs_PlanB_eSports_Cup_-_Ice.dm_60
# sweRTCW_UFO_Cup_Final_EYE_vs_GoL.dm_60
# demo0004.dm_60
# mp_beach-201638-{3kr}Saxxo.dm_59
# mp_beach-201943-{3kr}Saxxo.dm_59
# mp_beach-202220-{3kr}Saxxo.dm_59
# mp_beach-203116-{3kr}Saxxo.dm_59
# mp_assault-203611-{3kr}Saxxo.dm_59
# mp_assault-204830-{3kr}Saxxo.dm_59
# mp_assault-205459-{3kr}Saxxo.dm_59
# mp_assault-205811-{3kr}Saxxo.dm_59
# @vsZB_Assault_-_eSports_Cup.dm_60
# @vsZB_Ice_-_eSports_Cup.dm_60
# @vsZB_Beach_-_eSports_Cup.dm_60
# broken-ein-village_1.dm_57
# broken-ein-village.dm_57
# broken-ein-base.dm_57
# broken-ein-base-2.dm_57
# iN_vs_DkH_beach_1.dm_59
# iN_vs_DkH_beach_2.dm_59
# iN_vs_DkH_beach_3.dm_59
# 205054-WTV-@rtcw-ligade-mp_village.dm_60
# 205617-WTV-@rtcw-ligade-mp_village.dm_60
# 210717-WTV-@rtcw-ligade-mp_village.dm_60
# 211407-tzvensaw-mp_village.dm_60
# 212322-WTV-@rtcw-ligade-mp_beach.dm_60
# 212931-WTV-@rtcw-ligade-mp_beach.dm_60
# 213346-chesaw-mp_beach.dm_60
# 214336-cbwDABnpm-mp_beach.dm_60
# T34vWHY_-_eSports_Cup_-_Beach.dm_60
# T34vWHY_-_eSports_Cup_-_Base.dm_60
# 212226-32AriCk-mp_ice.dm_60
# 212713-32AriCk-mp_ice.dm_60
# 214527-IKIDoekoe-mp_base.dm_60
# 221411-44graden-mp_base.dm_60
# 224231-IKIEskiMo-mp_beach.dm_60
# 210759-frapit!-mp_beach.dm_60
# 212327-framote-mp_beach.dm_60
# 215004-frabandit-mp_village.dm_60
# 215434-framote-mp_village.dm_60
# demo-eso2invk.dm_60
# 182518-WTV-SpeakeasyNET-mp_village.dm_60
# 184320-[TAF]SpaRaT1k-mp_village.dm_60
# 185231-GMPOZAF'AMD-mp_village.dm_60
# 2003-08-15_214659-4K7Explicit-mp_village.dm_60
# 2003-08-15_215447-4K7Explicit-mp_village.dm_60
# 2003-08-15_220210-4K7Explicit-mp_village.dm_60
# POL_LAT_base1_1428720.dm_60
# POL_LAT_base2_1428720.dm_60
# POL_LAT_assault1_1428720.dm_60
# POL_LAT_assault2_1428720.dm_60
# 214053-ReneGadeo-mp_assault.dm_60
# 220203-syL_o-mp_assault.dm_60
# 221055-Fro$t-de_frostbite.dm_60
# MIvGX_eSports_Cup_-_Base.dm_59
# MIvGX_eSports_Cup_-_Beach.dm_59
# pM-AGB-depot_cb-11_30_sick1manzam.dm_57
# pM-AGB-assault_cb.dm_57
# SWE-DEN.APE.dm_60
# mp_sub-2002-08-16-224235-acitizen.dm_59
# mp_sub-2002-08-16-224616-acitizen.dm_59
# mp_sub-2002-08-16-224940-acitizen.dm_59
# mp_sub-2002-08-16-225729-acitizen.dm_59
# mp_sub-2002-08-16-231023-acitizen.dm_59
# 220736-{DP}Poopstix-mp_sub.dm_60
# 221327-{DP}Poopstix-mp_sub.dm_60
# 222140-{DP}Poopstix-mp_sub.dm_60
# 222356-{DP}Poopstix-mp_sub.dm_60
# 222716-{DP}Poopstix-mp_sub.dm_60
# 223021-{DP}Poopstix-mp_sub.dm_60
# 223301-{DP}Poopstix-mp_sub.dm_60
# wtv_mvsdr_final1.dm_59
# Noll8_vs_Euph_-_Beach_eSports_Cup.dm_60
# Noll8_vs_Euph_-_Sub_eSports_Cup.dm_60
# pbvsddt2.dm_59
# filled 400 matches in the database
# pM-Bod-village.dm_57
# mp_assault-030254-BoHH8red.dm_59
# mp_assault-030838-BoHH8red.dm_59
# mp_assault-032216-BoHH8red.dm_59
# pol_bel_mp_beach1_chase_1879964.dm_60
# pol_bel_mp_beach2_chase_1879964.dm_60
# pol_bel_mp_village1_chase_1879964.dm_60
# pol_bel_mp_village2a_chase_1879964.dm_60
# pol_bel_mp_village2b_chase_1879964.dm_60
# BOB_Empire_vs_Doctors_03_07_2002.dm_57
# mp_base-222306-vsePink.dm_59
# mp_base-223156-WTV-rtcwnospectator.dm_59
# mp_base-224447-WTV-rtcwnospectator.dm_59
# mp_beach-225253-WTV-rtcwnospectator.dm_59
# mp_beach-230405-WTV-rtcwnospectator.dm_59
# md-bully1.dm_57
# md-bully2.dm_57
# md-bully3.dm_57
# md-bully4.dm_57
# md-bully5.dm_57
# md-bully6.dm_57
# md-bully7.dm_57
# 044347-WTV-SpeakeasyNET-mp_beach.dm_60
# 045616-GMPOBLAZEAMD-mp_beach.dm_60
# 051749--!cF-50cenT-mp_beach.dm_60
# 213058-WTV-TnX-mp_beach.dm_60
# 214951-WTV-TnX-mp_beach.dm_60
# 221206-WTV-TnX-mp_beach.dm_60
# 222527-SnapS'CapteN-mp_ice.dm_60
# 225127-WTV-TnX-mp_ice.dm_60
# demo0001.dm_59
# 182016-savvaesports-mp_beach.dm_60
# 183821-savvaesports-mp_beach.dm_60
# 185200-savvaesports-mp_sub.dm_60
# 185747-savvaesports-mp_sub.dm_60
# pM-gpk-communique-1stomdefence_13_35_3mannadezam_3manpanzguystartingwithm_atsametimen_nice.dm_57
# pM-gpk-assault.dm_57
# 220526-IrrGsK-mp_beach.dm_60
# 222320-[T]k4O-mp_beach.dm_60
# udsazeice1.dm_60
# udsazefrostbite1.dm_60
# iM_vs_esp.dm_60
# mp_ice-005943-BoHH8red.dm_59
# mp_ice-011157-BoHH8red.dm_59
# mp_ice-012804-BoHH8red.dm_59
# all matches filled in database!
